# %% [markdown]
# # Advanced Lane Finding Project

# %% [markdown]
# #### The goals / steps of this project are the following:
#
# Compute the camera calibration matrix and distortion coefficients given a set of chessboard images.
# Apply a distortion correction to raw images.
# Use color transforms, gradients, etc., to create a thresholded binary image.
# Apply a perspective transform to rectify binary image ("birds-eye view").
# Detect lane pixels and fit to find the lane boundary.
# Determine the curvature of the lane and vehicle position with respect to center.
# Warp the detected lane boundaries back onto the original image.
# Output visual display of the lane boundaries and numerical estimation of lane curvature and vehicle position.

# %%
import numpy as np
import cv2
import pickle
import glob
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %matplotlib inline

# %% [markdown]
# ### Camera Calibration

# %%
objp = np.zeros((6*9,3), np.float32)
objp[:,:2] = np.mgrid[0:9,0:6].T.reshape(-1,2)

objpoints = []
imgpoints = []

images = glob.glob('camera_cal/calibration*.jpg')

fig, axs = plt.subplots(5,4, figsize=(16, 10))
axs = axs.ravel()

for i, fname in enumerate(images):
    img = cv2.imread(fname)
    gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    retval, corners = cv2.findChessboardCorners(gray_img, (9,6), None)
    
    if retval:
        objpoints.append(objp)
        imgpoints.append(corners)
        with_corners = cv2.drawChessboardCorners(img, (9,6), corners, retval)
        axs[i].imshow(img)

# %%
to_fix = cv2.imread('camera_cal/calibration3.jpg')
img_size = (to_fix.shape[1], to_fix.shape[0])

retval, camera_matrix, dist, rvecs, tvecs = cv2.calibrateCamera(objpoints, imgpoints, img_size, None, None)

fixed = cv2.undistort(to_fix, camera_matrix, dist, None, camera_matrix)
# cv2.imwrite('camera_cal/calibration2_undist.jpg',dst)

calib_pickle = {}
calib_pickle["camera_matrix"] = camera_matrix
calib_pickle["dist"] = dist
pickle.dump(calib_pickle, open("camera_cal/calib_pickle.p", "wb"));

# %%
_, (ax1, ax2) = plt.subplots(1, 2, figsize=(20,10));
ax1.imshow(to_fix)
ax1.set_title('Original')
ax2.imshow(fixed)
ax2.set_title('Undistorted')
plt.savefig('output_images/checkered_distortion.png')

# %%
test_image_BGR = cv2.imread('test_images/test1.jpg')
plt.imshow(cv2.cvtColor(test_image_BGR, cv2.COLOR_BGR2RGB))
test_image_LAB = cv2.cvtColor(test_image_BGR, cv2.COLOR_BGR2Lab)
test_image_HLS = cv2.cvtColor(test_image_BGR, cv2.COLOR_BGR2HLS)

# %%
test_image_B = test_image_BGR[:,:,0]
test_image_G = test_image_BGR[:,:,1]
test_image_R = test_image_BGR[:,:,2]
test_image_L = test_image_LAB[:,:,0]
test_image_A = test_image_LAB[:,:,1]
test_image_B2 = test_image_LAB[:,:,2]
test_image_H = test_image_HLS[:,:,0]
test_image_L2 = test_image_HLS[:,:,1]
test_image_S = test_image_HLS[:,:,2]

test_image_gray = cv2.cvtColor(test_image_BGR, cv2.COLOR_BGR2GRAY)

fig, axs = plt.subplots(3,3, figsize=(20, 20))

axs = axs.ravel()
axs[0].imshow(test_image_B, cmap='gray')
axs[1].imshow(test_image_G, cmap='gray')
axs[2].imshow(test_image_R, cmap='gray')
axs[3].imshow(test_image_L, cmap='gray')
axs[4].imshow(test_image_A, cmap='gray')
axs[5].imshow(test_image_B2, cmap='gray')
axs[6].imshow(test_image_H, cmap='gray')
axs[7].imshow(test_image_L2, cmap='gray')
axs[8].imshow(test_image_S, cmap='gray')

# %%
def sobel_with_thresholding(img, s_thresh=(100, 255), l_thresh=(40,255)):
    img = np.copy(img)
    
    hls = cv2.cvtColor(img, cv2.COLOR_BGR2HLS).astype(np.float)
    s_channel = hls[:,:,2]
    l_channel = hls[:,:,1]
    
    s_binary = np.zeros_like(s_channel)
    s_binary[(s_channel >= s_thresh[0]) & (s_channel <= s_thresh[1])] = 1

    l_binary = np.zeros_like(s_channel)
    l_binary[(l_channel >= l_thresh[0]) & (l_channel <= l_thresh[1])] = 1
    
    binary = np.zeros_like(s_channel)
    binary[(l_binary == 1) & (s_binary == 1)] = 1
    return 255*binary.astype('uint8')            

plt.imshow(sobel_with_threhsolding(test_image_BGR), cmap='gray')

# %%
def transform_perspective(img):
    h, w, _ = img.shape
    
    src = np.float32([(575,464),
                  (707,464), 
                  (258,682), 
                  (1049,682)])
    dst = np.float32([(450,0),
                      (w-450,0),
                      (450,h),
                      (w-450,h)])
    
    M = cv2.getPerspectiveTransform(src, dst)
    Minv = cv2.getPerspectiveTransform(dst, src)
    return cv2.warpPerspective(img, M, (w,h), flags=cv2.INTER_LINEAR), Minv

plt.imshow(transform_perspective(plt.imread('test_images/straight_lines1.jpg'))[0])

# %%
plt.imshow(plt.imread('test_images/straight_lines1.jpg'))

# %%
def pipeline(img):
    undistorted = cv2.undistort(img, camera_matrix, dist, None, camera_matrix)
    tfed, Minv = transform_perspective(undistorted)
    return sobel_with_thresholding(tfed), Minv
    
raw = plt.imread('test_images/straight_lines1.jpg')

plt.imshow(pipeline(raw)[0], cmap='gray')

# %%
def sliding_windows(binary_warped, show_image=False):
    
    histogram = np.sum(binary_warped[int(binary_warped.shape[0]/2):,:], axis=0)
    out_img = np.dstack((binary_warped, binary_warped, binary_warped))
    midpoint = np.int(histogram.shape[0]/2)
    leftx_base = np.argmax(histogram[:midpoint])
    rightx_base = np.argmax(histogram[midpoint:]) + midpoint
    nwindows = 9
    window_height = np.int(binary_warped.shape[0]/nwindows)
    nonzero = binary_warped.nonzero()
    nonzeroy = np.array(nonzero[0])
    nonzerox = np.array(nonzero[1])
    leftx_current = leftx_base
    rightx_current = rightx_base
    margin = 100
    minpix = 50
    left_lane_inds = []
    right_lane_inds = []
    
    for window in range(nwindows):
        win_y_low = binary_warped.shape[0] - (window+1)*window_height
        win_y_high = binary_warped.shape[0] - window*window_height
        win_xleft_low = leftx_current - margin
        win_xleft_high = leftx_current + margin
        win_xright_low = rightx_current - margin
        win_xright_high = rightx_current + margin
        cv2.rectangle(out_img,(win_xleft_low,win_y_low),(win_xleft_high,win_y_high),(0,255,0), 2) 
        cv2.rectangle(out_img,(win_xright_low,win_y_low),(win_xright_high,win_y_high),(0,255,0), 2) 
        good_left_inds = ((nonzeroy >= win_y_low) & (nonzeroy < win_y_high) & (nonzerox >= win_xleft_low) & (nonzerox < win_xleft_high)).nonzero()[0]
        good_right_inds = ((nonzeroy >= win_y_low) & (nonzeroy < win_y_high) & (nonzerox >= win_xright_low) & (nonzerox < win_xright_high)).nonzero()[0]
        left_lane_inds.append(good_left_inds)
        right_lane_inds.append(good_right_inds)
        if len(good_left_inds) > minpix:
            leftx_current = np.int(np.mean(nonzerox[good_left_inds]))
        if len(good_right_inds) > minpix:        
            rightx_current = np.int(np.mean(nonzerox[good_right_inds]))
            
    left_lane_inds = np.concatenate(left_lane_inds)
    right_lane_inds = np.concatenate(right_lane_inds)
    leftx = nonzerox[left_lane_inds]
    lefty = nonzeroy[left_lane_inds]
    rightx = nonzerox[right_lane_inds]
    righty = nonzeroy[right_lane_inds] 
    
    left_fit, right_fit = None, None
    if len(leftx) > 0:
        left_fit = np.polyfit(lefty, leftx, 2)
    if len(rightx) > 0:
        right_fit = np.polyfit(righty, rightx, 2)
    
    if show_image:
        ploty = np.linspace(0, binary_warped.shape[0]-1, binary_warped.shape[0])
        left_fitx = left_fit[0]*ploty**2 + left_fit[1]*ploty + left_fit[2]
        right_fitx = right_fit[0]*ploty**2 + right_fit[1]*ploty + right_fit[2]
    
        plt.imshow(out_img)
        plt.plot(left_fitx, ploty, color='yellow')
        plt.plot(right_fitx, ploty, color='yellow')
    
    return left_fit, right_fit, leftx, lefty, rightx, righty

# %%
def polyfit_with_prev_fits(binary_warped, left_prev, right_prev, show_image=False):
    
    nonzero = binary_warped.nonzero()
    nonzeroy = np.array(nonzero[0])
    nonzerox = np.array(nonzero[1])
    margin = 100
    left_lane_inds = ((nonzerox > (left_prev[0]*(nonzeroy**2) + left_prev[1]*nonzeroy + left_prev[2] - margin)) & 
                      (nonzerox < (left_prev[0]*(nonzeroy**2) + left_prev[1]*nonzeroy + left_prev[2] + margin))) 
    right_lane_inds = ((nonzerox > (right_prev[0]*(nonzeroy**2) + right_prev[1]*nonzeroy + right_prev[2] - margin)) & 
                       (nonzerox < (right_prev[0]*(nonzeroy**2) + right_prev[1]*nonzeroy + right_prev[2] + margin)))  

    # Again, extract left and right line pixel positions
    leftx = nonzerox[left_lane_inds]
    lefty = nonzeroy[left_lane_inds] 
    rightx = nonzerox[right_lane_inds]
    righty = nonzeroy[right_lane_inds]
    
    left_fit_new, right_fit_new = None, None
    if len(leftx) > 0:
        left_fit_new = np.polyfit(lefty, leftx, 2)
    if len(rightx) > 0:
        right_fit_new = np.polyfit(righty, rightx, 2)

    
    if show_image:
        ploty = np.linspace(0, binary_warped.shape[0]-1, binary_warped.shape[0])
        left_fitx = left_fit_new[0]*ploty**2 + left_fit_new[1]*ploty + left_fit_new[2]
        right_fitx = right_fit_new[0]*ploty**2 + right_fit_new[1]*ploty + right_fit_new[2]
        # Create an image to draw on and an image to show the selection window
        out_img = np.dstack((binary_warped, binary_warped, binary_warped))*255
        window_img = np.zeros_like(out_img)
        # Color in left and right line pixels
        out_img[nonzeroy[left_lane_inds], nonzerox[left_lane_inds]] = [255, 0, 0]
        out_img[nonzeroy[right_lane_inds], nonzerox[right_lane_inds]] = [0, 0, 255]

        # Generate a polygon to illustrate the search window area
        # And recast the x and y points into usable format for cv2.fillPoly()
        left_line_window1 = np.array([np.transpose(np.vstack([left_fitx-margin, ploty]))])
        left_line_window2 = np.array([np.flipud(np.transpose(np.vstack([left_fitx+margin, 
                                      ploty])))])
        left_line_pts = np.hstack((left_line_window1, left_line_window2))
        right_line_window1 = np.array([np.transpose(np.vstack([right_fitx-margin, ploty]))])
        right_line_window2 = np.array([np.flipud(np.transpose(np.vstack([right_fitx+margin, 
                                      ploty])))])
        right_line_pts = np.hstack((right_line_window1, right_line_window2))

        # Draw the lane onto the warped blank image
        cv2.fillPoly(window_img, np.int_([left_line_pts]), (0,255, 0))
        cv2.fillPoly(window_img, np.int_([right_line_pts]), (0,255, 0))
        result = cv2.addWeighted(out_img, 1, window_img, 0.3, 0)
        plt.imshow(result)
        plt.plot(left_fitx, ploty, color='yellow')
        plt.plot(right_fitx, ploty, color='yellow')
        plt.xlim(0, 1280)
        plt.ylim(720, 0)
    
    return left_fit_new, right_fit_new, leftx, lefty, rightx, righty

# %%
example_img = cv2.imread('./test_images/test3.jpg')
example_img = cv2.cvtColor(example_img, cv2.COLOR_BGR2RGB)
example_img_bin, Minv = pipeline(example_img)
    
left_fit, right_fit, *_ = sliding_windows(example_img_bin)
_, _, *points = polyfit_with_prev_fits(example_img_bin, left_fit, right_fit, True)

# %%
# measure curvature ... see 
# https://classroom.udacity.com/nanodegrees/nd013/parts/fbf77062-5703-404e-b60c-95b78b2f3f9e/modules/2b62a1c3-e151-4a0e-b6b6-e424fa46ceab/lessons/096009a1-3d76-4290-92f3-055961019d5e/concepts/2f928913-21f6-4611-9055-01744acc344f

def calc_curv_rad(bin_img, leftx, lefty, rightx, righty):
    h, w = bin_img.shape
    ym_per_pix = 3.048/100 # meters per pixel in y dimension
    xm_per_pix = 3.7/370 # meters per pixel in x dimension
    
    if len(leftx) <= 0 or len(rightx) <= 0:
        return None, None, None

    y_eval = h
    # Fit new polynomials to x,y in world space
    left_fit_cr = np.polyfit(lefty*ym_per_pix, leftx*xm_per_pix, 2)
    right_fit_cr = np.polyfit(righty*ym_per_pix, rightx*xm_per_pix, 2)
    # Calculate the new radii of curvature
    left_curverad = ((1 + (2*left_fit_cr[0]*y_eval*ym_per_pix + left_fit_cr[1])**2)**1.5) / np.absolute(2*left_fit_cr[0])
    right_curverad = ((1 + (2*right_fit_cr[0]*y_eval*ym_per_pix + right_fit_cr[1])**2)**1.5) / np.absolute(2*right_fit_cr[0])
    
    h_scaled = h*ym_per_pix
    l_fit_start = left_fit_cr[0]*h_scaled**2 + left_fit_cr[1]*h_scaled + left_fit_cr[2]
    r_fit_start = right_fit_cr[0]*h_scaled**2 + right_fit_cr[1]*h_scaled + right_fit_cr[2]
    lane_center = (l_fit_start + r_fit_start)/2
    car_center = w/2*xm_per_pix
    dist_from_center = w/2*xm_per_pix - lane_center
    return left_curverad, right_curverad, dist_from_center

# %%
radl, radr, dist_from_center = calc_curv_rad(example_img_bin, *points)

# %%
# draw the overlay on the original image
# also add text

def draw_lane(original_img, binary_img, l_fit, r_fit, Minv):
    new_img = np.copy(original_img)
    if l_fit is None or r_fit is None:
        return original_img
    
    warp_zero = np.zeros_like(binary_img, dtype=np.uint8)
    color_warp = np.dstack((warp_zero, warp_zero, warp_zero))
    
    h,w = binary_img.shape
    ploty = np.linspace(0, h-1, num=h)
    left_fitx = l_fit[0]*ploty**2 + l_fit[1]*ploty + l_fit[2]
    right_fitx = r_fit[0]*ploty**2 + r_fit[1]*ploty + r_fit[2]

    pts_left = np.array([np.vstack([left_fitx, ploty]).T], dtype=np.int32)
    pts_right = np.array([np.flipud(np.vstack([right_fitx, ploty]).T)], dtype=np.int32)
    pts = np.array(np.hstack((pts_left, pts_right)).astype(np.int_))

    cv2.fillPoly(color_warp, pts, (0, 255, 0))
    cv2.polylines(color_warp, pts_left, isClosed=False, color=(255,0,255), thickness=10)
    cv2.polylines(color_warp, pts_right, isClosed=False, color=(0,255,255), thickness=10)

    unwarped = cv2.warpPerspective(color_warp, Minv, (w, h)) 
    return cv2.addWeighted(new_img, 1, unwarped, 0.5, 0)

def draw_text(original_img, radl, radr, dist_from_center):
    if not radl or not radr or not dist_from_center:
        return original_img
    
    curv_rad = (radl+radr)/2
    
    scale = 2
    thickness = 2
    color = (200, 255, 155)
    new_img = np.copy(original_img)
    h = new_img.shape[0]
    font = cv2.FONT_HERSHEY_PLAIN
    text = 'Curve radius: ' + '{:04.2f}'.format(curv_rad) + 'm'
    cv2.putText(new_img, text, (40,40), font, scale, color, thickness, cv2.LINE_AA)
    
    direction = ''
    if dist_from_center > 0:
        direction = 'right'
    elif dist_from_center < 0:
        direction = 'left'
    text = '{:04.3f}'.format(abs(dist_from_center)) + 'm ' + direction + ' of center'
    cv2.putText(new_img, text, (40,80), font, scale, color, thickness, cv2.LINE_AA)
    return new_img

# %%
# write code for processing one whole image
# write code for processing video
example_with_lane = draw_lane(example_img, example_img_bin, left_fit, right_fit, Minv)
plt.imshow(example_with_lane)

# %%
example_with_text = draw_text(example_with_lane, radl, radr, dist_from_center)
plt.imshow(example_with_text)

# %%
def generate_image(img):
    new_img = np.copy(img)
    img_bin, Minv = pipeline(new_img)
    
    if True:
        left_fit, right_fit, *points = sliding_windows(img_bin)
        radl, radr, dist_from_center = calc_curv_rad(img_bin, *points)
        with_lane = draw_lane(new_img, img_bin, left_fit, right_fit, Minv)
        with_text = draw_text(with_lane, radl, radr, dist_from_center)
        return with_text
    #else:
    #    left_fit, right_fit, *points = polyfit_with_prev_fits(img_bin, left_fit, right_fit)
    #    radl, radr, dist_from_center = calc_curv_rad(img_bin, *points)
    #    with_lane = draw_lane(new_img, img_bin, left_fit, right_fit, Minv)
    #    with_text = draw_text(with_lane, radl, radr, dist_from_center)
    #    return with_text

# %%
test_img = generate_image(example_img)
plt.imshow(test_img)

# %%
from moviepy.editor import VideoFileClip

output_path = 'video_output.mp4'
video_input = VideoFileClip('project_video.mp4')
processed_video = video_input.fl_image(generate_image)
# %time processed_video.write_videofile(output_path, audio=False)
# Out:
# [MoviePy] >>>> Building video video_output.mp4
# [MoviePy] Writing video video_output.mp4
#   0%|          | 0/1261 [00:00<?, ?it/s]
#   0%|          | 1/1261 [00:00<03:01,  6.93it/s]
#   0%|          | 2/1261 [00:00<02:53,  7.25it/s]
#   0%|          | 3/1261 [00:00<02:45,  7.61it/s]
#   0%|          | 4/1261 [00:00<02:39,  7.87it/s]
#   0%|          | 5/1261 [00:00<02:38,  7.93it/s]
#   0%|          | 6/1261 [00:00<02:36,  8.00it/s]
#   1%|          | 7/1261 [00:00<02:32,  8.21it/s]
#   1%|          | 8/1261 [00:00<02:29,  8.39it/s]
#   1%|          | 9/1261 [00:01<02:28,  8.43it/s]
#   1%|          | 10/1261 [00:01<02:28,  8.40it/s]
#   1%|          | 11/1261 [00:01<02:29,  8.36it/s]
#   1%|          | 12/1261 [00:01<02:33,  8.15it/s]
#   1%|          | 13/1261 [00:01<02:34,  8.08it/s]
#   1%|          | 14/1261 [00:01<02:32,  8.17it/s]
#   1%|          | 15/1261 [00:01<02:30,  8.27it/s]
#   1%|▏         | 16/1261 [00:01<02:28,  8.37it/s]
#   1%|▏         | 17/1261 [00:02<02:28,  8.40it/s]
#   1%|▏         | 18/1261 [00:02<02:26,  8.47it/s]
#   2%|▏         | 19/1261 [00:02<02:25,  8.55it/s]
#   2%|▏         | 20/1261 [00:02<02:24,  8.59it/s]
#   2%|▏         | 21/1261 [00:02<02:23,  8.63it/s]
#   2%|▏         | 22/1261 [00:02<02:22,  8.69it/s]
#   2%|▏         | 23/1261 [00:02<02:23,  8.60it/s]
#   2%|▏         | 24/1261 [00:02<02:23,  8.61it/s]
#   2%|▏         | 25/1261 [00:02<02:24,  8.52it/s]
#   2%|▏         | 26/1261 [00:03<02:28,  8.31it/s]
#   2%|▏         | 27/1261 [00:03<02:28,  8.28it/s]
#   2%|▏         | 28/1261 [00:03<02:27,  8.35it/s]
#   2%|▏         | 29/1261 [00:03<02:26,  8.40it/s]
#   2%|▏         | 30/1261 [00:03<02:26,  8.43it/s]
#   2%|▏         | 31/1261 [00:03<02:25,  8.47it/s]
#   3%|▎         | 32/1261 [00:03<02:25,  8.46it/s]
#   3%|▎         | 33/1261 [00:03<02:24,  8.48it/s]
#   3%|▎         | 34/1261 [00:04<02:23,  8.53it/s]
#   3%|▎         | 35/1261 [00:04<02:23,  8.53it/s]
#   3%|▎         | 36/1261 [00:04<02:24,  8.48it/s]
#   3%|▎         | 37/1261 [00:04<02:24,  8.48it/s]
#   3%|▎         | 38/1261 [00:04<02:22,  8.59it/s]
#   3%|▎         | 39/1261 [00:04<02:23,  8.55it/s]
#   3%|▎         | 40/1261 [00:04<02:21,  8.65it/s]
#   3%|▎         | 41/1261 [00:04<02:20,  8.71it/s]
#   3%|▎         | 42/1261 [00:04<02:20,  8.68it/s]
#   3%|▎         | 43/1261 [00:05<02:26,  8.32it/s]
#   3%|▎         | 44/1261 [00:05<02:32,  7.98it/s]
#   4%|▎         | 45/1261 [00:05<02:34,  7.88it/s]
#   4%|▎         | 46/1261 [00:05<02:29,  8.11it/s]
#   4%|▎         | 47/1261 [00:05<02:28,  8.19it/s]
#   4%|▍         | 48/1261 [00:05<02:43,  7.40it/s]
#   4%|▍         | 49/1261 [00:05<02:47,  7.24it/s]
#   4%|▍         | 50/1261 [00:06<02:47,  7.24it/s]
#   4%|▍         | 51/1261 [00:06<02:43,  7.38it/s]
#   4%|▍         | 52/1261 [00:06<02:54,  6.93it/s]
#   4%|▍         | 53/1261 [00:06<02:48,  7.17it/s]
#   4%|▍         | 54/1261 [00:06<02:43,  7.36it/s]
#   4%|▍         | 55/1261 [00:06<02:46,  7.22it/s]
#   4%|▍         | 56/1261 [00:06<03:08,  6.40it/s]
#   5%|▍         | 57/1261 [00:07<03:45,  5.33it/s]
#   5%|▍         | 58/1261 [00:07<04:04,  4.93it/s]
#   5%|▍         | 59/1261 [00:07<04:20,  4.62it/s]
#   5%|▍         | 60/1261 [00:07<03:49,  5.22it/s]
#   5%|▍         | 61/1261 [00:07<03:34,  5.60it/s]
#   5%|▍         | 62/1261 [00:08<03:26,  5.82it/s]
#   5%|▍         | 63/1261 [00:08<03:34,  5.58it/s]
#   5%|▌         | 64/1261 [00:08<03:34,  5.58it/s]
#   5%|▌         | 65/1261 [00:08<03:21,  5.93it/s]
#   5%|▌         | 66/1261 [00:08<03:17,  6.06it/s]
#   5%|▌         | 67/1261 [00:09<03:38,  5.46it/s]
#   5%|▌         | 68/1261 [00:09<03:24,  5.83it/s]
#   5%|▌         | 69/1261 [00:09<03:04,  6.46it/s]
#   6%|▌         | 70/1261 [00:09<02:49,  7.04it/s]
#   6%|▌         | 71/1261 [00:09<02:55,  6.77it/s]
#   6%|▌         | 72/1261 [00:09<02:47,  7.12it/s]
#   6%|▌         | 73/1261 [00:09<02:37,  7.53it/s]
#   6%|▌         | 74/1261 [00:09<02:38,  7.50it/s]
#   6%|▌         | 75/1261 [00:10<02:36,  7.58it/s]
#   6%|▌         | 76/1261 [00:10<02:40,  7.37it/s]
#   6%|▌         | 77/1261 [00:10<02:51,  6.89it/s]
#   6%|▌         | 78/1261 [00:10<02:51,  6.92it/s]
#   6%|▋         | 79/1261 [00:10<03:20,  5.89it/s]
#   6%|▋         | 80/1261 [00:10<03:10,  6.20it/s]
#   6%|▋         | 81/1261 [00:11<03:18,  5.95it/s]
#   7%|▋         | 82/1261 [00:11<03:14,  6.05it/s]
#   7%|▋         | 83/1261 [00:11<03:21,  5.83it/s]
#   7%|▋         | 84/1261 [00:11<03:04,  6.37it/s]
#   7%|▋         | 85/1261 [00:11<02:53,  6.79it/s]
#   7%|▋         | 86/1261 [00:11<02:50,  6.91it/s]
#   7%|▋         | 87/1261 [00:12<03:08,  6.22it/s]
#   7%|▋         | 88/1261 [00:12<03:08,  6.22it/s]
#   7%|▋         | 89/1261 [00:12<02:56,  6.64it/s]
#   7%|▋         | 90/1261 [00:12<02:49,  6.89it/s]
#   7%|▋         | 91/1261 [00:12<03:04,  6.35it/s]
#   7%|▋         | 92/1261 [00:12<03:00,  6.47it/s]
#   7%|▋         | 93/1261 [00:12<03:01,  6.43it/s]
#   7%|▋         | 94/1261 [00:13<02:54,  6.70it/s]
#   8%|▊         | 95/1261 [00:13<02:53,  6.71it/s]
#   8%|▊         | 96/1261 [00:13<02:45,  7.04it/s]
#   8%|▊         | 97/1261 [00:13<02:47,  6.97it/s]
#   8%|▊         | 98/1261 [00:13<03:03,  6.34it/s]
#   8%|▊         | 99/1261 [00:13<03:00,  6.43it/s]
#   8%|▊         | 100/1261 [00:13<03:00,  6.44it/s]
#   8%|▊         | 101/1261 [00:14<03:06,  6.22it/s]
#   8%|▊         | 102/1261 [00:14<03:19,  5.81it/s]
#   8%|▊         | 103/1261 [00:14<03:16,  5.88it/s]
#   8%|▊         | 104/1261 [00:14<03:04,  6.26it/s]
#   8%|▊         | 105/1261 [00:14<02:52,  6.68it/s]
#   8%|▊         | 106/1261 [00:14<02:53,  6.64it/s]
#   8%|▊         | 107/1261 [00:15<02:56,  6.54it/s]
#   9%|▊         | 108/1261 [00:15<02:54,  6.60it/s]
#   9%|▊         | 109/1261 [00:15<02:55,  6.56it/s]
#   9%|▊         | 110/1261 [00:15<03:01,  6.35it/s]
#   9%|▉         | 111/1261 [00:15<03:09,  6.05it/s]
#   9%|▉         | 112/1261 [00:15<03:21,  5.69it/s]
#   9%|▉         | 113/1261 [00:16<03:37,  5.27it/s]
#   9%|▉         | 114/1261 [00:16<04:06,  4.66it/s]
#   9%|▉         | 115/1261 [00:16<03:43,  5.13it/s]
#   9%|▉         | 116/1261 [00:16<03:20,  5.70it/s]
#   9%|▉         | 117/1261 [00:16<03:05,  6.16it/s]
#   9%|▉         | 118/1261 [00:16<02:57,  6.44it/s]
#   9%|▉         | 119/1261 [00:17<02:46,  6.85it/s]
#  10%|▉         | 120/1261 [00:17<02:38,  7.20it/s]
#  10%|▉         | 121/1261 [00:17<02:30,  7.60it/s]
#  10%|▉         | 122/1261 [00:17<02:23,  7.96it/s]
#  10%|▉         | 123/1261 [00:17<02:19,  8.17it/s]
#  10%|▉         | 124/1261 [00:17<02:19,  8.17it/s]
#  10%|▉         | 125/1261 [00:17<02:17,  8.26it/s]
#  10%|▉         | 126/1261 [00:17<02:20,  8.07it/s]
#  10%|█         | 127/1261 [00:18<02:19,  8.11it/s]
#  10%|█         | 128/1261 [00:18<02:21,  7.99it/s]
#  10%|█         | 129/1261 [00:18<02:18,  8.15it/s]
#  10%|█         | 130/1261 [00:18<02:15,  8.36it/s]
#  10%|█         | 131/1261 [00:18<02:12,  8.52it/s]
#  10%|█         | 132/1261 [00:18<02:25,  7.75it/s]
#  11%|█         | 133/1261 [00:18<02:28,  7.59it/s]
#  11%|█         | 134/1261 [00:18<02:25,  7.73it/s]
#  11%|█         | 135/1261 [00:19<02:26,  7.71it/s]
#  11%|█         | 136/1261 [00:19<02:27,  7.61it/s]
#  11%|█         | 137/1261 [00:19<02:23,  7.85it/s]
#  11%|█         | 138/1261 [00:19<02:20,  7.98it/s]
#  11%|█         | 139/1261 [00:19<02:17,  8.17it/s]
#  11%|█         | 140/1261 [00:19<02:15,  8.25it/s]
#  11%|█         | 141/1261 [00:19<02:13,  8.39it/s]
#  11%|█▏        | 142/1261 [00:19<02:15,  8.24it/s]
#  11%|█▏        | 143/1261 [00:20<02:12,  8.45it/s]
#  11%|█▏        | 144/1261 [00:20<02:14,  8.33it/s]
#  11%|█▏        | 145/1261 [00:20<02:12,  8.44it/s]
#  12%|█▏        | 146/1261 [00:20<02:10,  8.51it/s]
#  12%|█▏        | 147/1261 [00:20<02:09,  8.61it/s]
#  12%|█▏        | 148/1261 [00:20<02:11,  8.47it/s]
#  12%|█▏        | 149/1261 [00:20<02:09,  8.58it/s]
#  12%|█▏        | 150/1261 [00:20<02:09,  8.60it/s]
#  12%|█▏        | 151/1261 [00:20<02:09,  8.56it/s]
#  12%|█▏        | 152/1261 [00:21<02:13,  8.31it/s]
#  12%|█▏        | 153/1261 [00:21<02:10,  8.48it/s]
#  12%|█▏        | 154/1261 [00:21<02:10,  8.51it/s]
#  12%|█▏        | 155/1261 [00:21<02:15,  8.19it/s]
#  12%|█▏        | 156/1261 [00:21<02:18,  7.98it/s]
#  12%|█▏        | 157/1261 [00:21<02:17,  8.04it/s]
#  13%|█▎        | 158/1261 [00:21<02:22,  7.73it/s]
#  13%|█▎        | 159/1261 [00:22<02:23,  7.67it/s]
#  13%|█▎        | 160/1261 [00:22<02:25,  7.57it/s]
#  13%|█▎        | 161/1261 [00:22<02:26,  7.53it/s]
#  13%|█▎        | 162/1261 [00:22<02:23,  7.67it/s]
#  13%|█▎        | 163/1261 [00:22<02:33,  7.14it/s]
#  13%|█▎        | 164/1261 [00:22<02:32,  7.19it/s]
#  13%|█▎        | 165/1261 [00:22<02:45,  6.62it/s]
#  13%|█▎        | 166/1261 [00:23<02:48,  6.49it/s]
#  13%|█▎        | 167/1261 [00:23<02:47,  6.52it/s]
#  13%|█▎        | 168/1261 [00:23<03:02,  5.98it/s]
#  13%|█▎        | 169/1261 [00:23<03:00,  6.04it/s]
#  13%|█▎        | 170/1261 [00:23<02:55,  6.23it/s]
#  14%|█▎        | 171/1261 [00:23<02:48,  6.46it/s]
#  14%|█▎        | 172/1261 [00:23<02:40,  6.79it/s]
#  14%|█▎        | 173/1261 [00:24<02:34,  7.05it/s]
#  14%|█▍        | 174/1261 [00:24<02:31,  7.17it/s]
#  14%|█▍        | 175/1261 [00:24<02:32,  7.11it/s]
#  14%|█▍        | 176/1261 [00:24<02:37,  6.89it/s]
#  14%|█▍        | 177/1261 [00:24<02:46,  6.53it/s]
#  14%|█▍        | 178/1261 [00:24<02:43,  6.64it/s]
#  14%|█▍        | 179/1261 [00:24<02:38,  6.81it/s]
#  14%|█▍        | 180/1261 [00:25<02:35,  6.96it/s]
#  14%|█▍        | 181/1261 [00:25<02:28,  7.28it/s]
#  14%|█▍        | 182/1261 [00:25<02:21,  7.63it/s]
#  15%|█▍        | 183/1261 [00:25<02:19,  7.73it/s]
#  15%|█▍        | 184/1261 [00:25<02:41,  6.67it/s]
#  15%|█▍        | 185/1261 [00:25<02:47,  6.44it/s]
#  15%|█▍        | 186/1261 [00:26<02:45,  6.48it/s]
#  15%|█▍        | 187/1261 [00:26<02:47,  6.40it/s]
#  15%|█▍        | 188/1261 [00:26<02:55,  6.13it/s]
#  15%|█▍        | 189/1261 [00:26<03:03,  5.86it/s]
#  15%|█▌        | 190/1261 [00:26<03:09,  5.67it/s]
#  15%|█▌        | 191/1261 [00:26<03:04,  5.80it/s]
#  15%|█▌        | 192/1261 [00:27<02:55,  6.10it/s]
#  15%|█▌        | 193/1261 [00:27<02:40,  6.66it/s]
#  15%|█▌        | 194/1261 [00:27<02:32,  6.98it/s]
#  15%|█▌        | 195/1261 [00:27<02:31,  7.02it/s]
#  16%|█▌        | 196/1261 [00:27<02:49,  6.29it/s]
#  16%|█▌        | 197/1261 [00:27<02:47,  6.34it/s]
#  16%|█▌        | 198/1261 [00:27<02:49,  6.27it/s]
#  16%|█▌        | 199/1261 [00:28<02:49,  6.26it/s]
#  16%|█▌        | 200/1261 [00:28<03:04,  5.75it/s]
#  16%|█▌        | 201/1261 [00:28<03:06,  5.69it/s]
#  16%|█▌        | 202/1261 [00:28<02:58,  5.92it/s]
#  16%|█▌        | 203/1261 [00:28<02:49,  6.25it/s]
#  16%|█▌        | 204/1261 [00:29<03:45,  4.68it/s]
#  16%|█▋        | 205/1261 [00:29<04:17,  4.11it/s]
#  16%|█▋        | 206/1261 [00:29<04:23,  4.00it/s]
#  16%|█▋        | 207/1261 [00:29<03:48,  4.61it/s]
#  16%|█▋        | 208/1261 [00:30<03:33,  4.93it/s]
#  17%|█▋        | 209/1261 [00:30<03:22,  5.20it/s]
#  17%|█▋        | 210/1261 [00:30<03:20,  5.24it/s]
#  17%|█▋        | 211/1261 [00:30<03:29,  5.00it/s]
#  17%|█▋        | 212/1261 [00:30<03:08,  5.56it/s]
#  17%|█▋        | 213/1261 [00:30<02:47,  6.25it/s]
#  17%|█▋        | 214/1261 [00:30<02:33,  6.82it/s]
#  17%|█▋        | 215/1261 [00:31<02:23,  7.27it/s]
#  17%|█▋        | 216/1261 [00:31<02:23,  7.27it/s]
#  17%|█▋        | 217/1261 [00:31<02:33,  6.78it/s]
#  17%|█▋        | 218/1261 [00:31<02:27,  7.07it/s]
#  17%|█▋        | 219/1261 [00:31<02:23,  7.25it/s]
#  17%|█▋        | 220/1261 [00:31<02:27,  7.05it/s]
#  18%|█▊        | 221/1261 [00:31<02:26,  7.08it/s]
#  18%|█▊        | 222/1261 [00:32<02:23,  7.22it/s]
#  18%|█▊        | 223/1261 [00:32<02:35,  6.67it/s]
#  18%|█▊        | 224/1261 [00:32<02:34,  6.71it/s]
#  18%|█▊        | 225/1261 [00:32<02:34,  6.73it/s]
#  18%|█▊        | 226/1261 [00:32<02:29,  6.94it/s]
#  18%|█▊        | 227/1261 [00:32<02:26,  7.07it/s]
#  18%|█▊        | 228/1261 [00:32<02:31,  6.83it/s]
#  18%|█▊        | 229/1261 [00:33<02:22,  7.23it/s]
#  18%|█▊        | 230/1261 [00:33<02:17,  7.50it/s]
#  18%|█▊        | 231/1261 [00:33<02:27,  6.99it/s]
#  18%|█▊        | 232/1261 [00:33<02:33,  6.72it/s]
#  18%|█▊        | 233/1261 [00:33<02:25,  7.08it/s]
#  19%|█▊        | 234/1261 [00:33<02:15,  7.55it/s]
#  19%|█▊        | 235/1261 [00:33<02:11,  7.83it/s]
#  19%|█▊        | 236/1261 [00:34<02:12,  7.74it/s]
#  19%|█▉        | 237/1261 [00:34<02:10,  7.86it/s]
#  19%|█▉        | 238/1261 [00:34<02:35,  6.58it/s]
#  19%|█▉        | 239/1261 [00:34<02:44,  6.22it/s]
#  19%|█▉        | 240/1261 [00:34<02:56,  5.79it/s]
#  19%|█▉        | 241/1261 [00:34<02:40,  6.35it/s]
#  19%|█▉        | 242/1261 [00:34<02:27,  6.91it/s]
#  19%|█▉        | 243/1261 [00:35<02:19,  7.29it/s]
#  19%|█▉        | 244/1261 [00:35<02:21,  7.18it/s]
#  19%|█▉        | 245/1261 [00:35<02:18,  7.33it/s]
#  20%|█▉        | 246/1261 [00:35<02:14,  7.55it/s]
#  20%|█▉        | 247/1261 [00:35<02:07,  7.96it/s]
#  20%|█▉        | 248/1261 [00:35<02:05,  8.08it/s]
#  20%|█▉        | 249/1261 [00:35<02:04,  8.12it/s]
#  20%|█▉        | 250/1261 [00:35<02:03,  8.17it/s]
#  20%|█▉        | 251/1261 [00:36<02:00,  8.42it/s]
#  20%|█▉        | 252/1261 [00:36<02:02,  8.22it/s]
#  20%|██        | 253/1261 [00:36<02:00,  8.34it/s]
#  20%|██        | 254/1261 [00:36<02:01,  8.26it/s]
#  20%|██        | 255/1261 [00:36<01:59,  8.44it/s]
#  20%|██        | 256/1261 [00:36<02:00,  8.35it/s]
#  20%|██        | 257/1261 [00:36<01:58,  8.45it/s]
#  20%|██        | 258/1261 [00:36<01:56,  8.60it/s]
#  21%|██        | 259/1261 [00:37<01:59,  8.36it/s]
#  21%|██        | 260/1261 [00:37<02:05,  7.97it/s]
#  21%|██        | 261/1261 [00:37<02:07,  7.86it/s]
#  21%|██        | 262/1261 [00:37<02:11,  7.62it/s]
#  21%|██        | 263/1261 [00:37<02:08,  7.78it/s]
#  21%|██        | 264/1261 [00:37<02:14,  7.41it/s]
#  21%|██        | 265/1261 [00:37<02:10,  7.63it/s]
#  21%|██        | 266/1261 [00:37<02:08,  7.74it/s]
#  21%|██        | 267/1261 [00:38<02:05,  7.95it/s]
#  21%|██▏       | 268/1261 [00:38<02:02,  8.09it/s]
#  21%|██▏       | 269/1261 [00:38<01:59,  8.33it/s]
#  21%|██▏       | 270/1261 [00:38<02:06,  7.83it/s]
#  21%|██▏       | 271/1261 [00:38<02:07,  7.75it/s]
#  22%|██▏       | 272/1261 [00:38<02:06,  7.80it/s]
#  22%|██▏       | 273/1261 [00:38<02:02,  8.04it/s]
#  22%|██▏       | 274/1261 [00:38<02:04,  7.95it/s]
#  22%|██▏       | 275/1261 [00:39<02:07,  7.73it/s]
#  22%|██▏       | 276/1261 [00:39<02:07,  7.73it/s]
#  22%|██▏       | 277/1261 [00:39<02:04,  7.90it/s]
#  22%|██▏       | 278/1261 [00:39<02:04,  7.92it/s]
#  22%|██▏       | 279/1261 [00:39<02:05,  7.85it/s]
#  22%|██▏       | 280/1261 [00:39<02:04,  7.91it/s]
#  22%|██▏       | 281/1261 [00:39<01:59,  8.21it/s]
#  22%|██▏       | 282/1261 [00:39<01:55,  8.47it/s]
#  22%|██▏       | 283/1261 [00:40<01:56,  8.37it/s]
#  23%|██▎       | 284/1261 [00:40<01:56,  8.37it/s]
#  23%|██▎       | 285/1261 [00:40<01:54,  8.55it/s]
#  23%|██▎       | 286/1261 [00:40<01:54,  8.49it/s]
#  23%|██▎       | 287/1261 [00:40<02:00,  8.06it/s]
#  23%|██▎       | 288/1261 [00:40<02:05,  7.73it/s]
#  23%|██▎       | 289/1261 [00:40<02:01,  7.99it/s]
#  23%|██▎       | 290/1261 [00:40<01:58,  8.22it/s]
#  23%|██▎       | 291/1261 [00:41<01:54,  8.47it/s]
#  23%|██▎       | 292/1261 [00:41<01:58,  8.19it/s]
#  23%|██▎       | 293/1261 [00:41<02:10,  7.44it/s]
#  23%|██▎       | 294/1261 [00:41<02:11,  7.35it/s]
#  23%|██▎       | 295/1261 [00:41<02:14,  7.18it/s]
#  23%|██▎       | 296/1261 [00:41<02:12,  7.30it/s]
#  24%|██▎       | 297/1261 [00:41<02:06,  7.60it/s]
#  24%|██▎       | 298/1261 [00:41<02:03,  7.82it/s]
#  24%|██▎       | 299/1261 [00:42<01:58,  8.14it/s]
#  24%|██▍       | 300/1261 [00:42<02:00,  7.97it/s]
#  24%|██▍       | 301/1261 [00:42<01:57,  8.15it/s]
#  24%|██▍       | 302/1261 [00:42<01:57,  8.17it/s]
#  24%|██▍       | 303/1261 [00:42<01:54,  8.40it/s]
#  24%|██▍       | 304/1261 [00:42<01:51,  8.57it/s]
#  24%|██▍       | 305/1261 [00:42<01:49,  8.71it/s]
#  24%|██▍       | 306/1261 [00:42<01:52,  8.48it/s]
#  24%|██▍       | 307/1261 [00:43<01:52,  8.51it/s]
#  24%|██▍       | 308/1261 [00:43<01:53,  8.36it/s]
#  25%|██▍       | 309/1261 [00:43<01:52,  8.44it/s]
#  25%|██▍       | 310/1261 [00:43<01:57,  8.09it/s]
#  25%|██▍       | 311/1261 [00:43<01:55,  8.20it/s]
#  25%|██▍       | 312/1261 [00:43<01:54,  8.26it/s]
#  25%|██▍       | 313/1261 [00:43<01:55,  8.18it/s]
#  25%|██▍       | 314/1261 [00:43<02:01,  7.82it/s]
#  25%|██▍       | 315/1261 [00:44<02:02,  7.74it/s]
#  25%|██▌       | 316/1261 [00:44<01:59,  7.92it/s]
#  25%|██▌       | 317/1261 [00:44<01:54,  8.25it/s]
#  25%|██▌       | 318/1261 [00:44<01:53,  8.31it/s]
#  25%|██▌       | 319/1261 [00:44<01:50,  8.51it/s]
#  25%|██▌       | 320/1261 [00:44<01:48,  8.65it/s]
#  25%|██▌       | 321/1261 [00:44<01:47,  8.74it/s]
#  26%|██▌       | 322/1261 [00:44<01:48,  8.66it/s]
#  26%|██▌       | 323/1261 [00:44<01:47,  8.74it/s]
#  26%|██▌       | 324/1261 [00:45<01:46,  8.77it/s]
#  26%|██▌       | 325/1261 [00:45<01:47,  8.73it/s]
#  26%|██▌       | 326/1261 [00:45<01:55,  8.09it/s]
#  26%|██▌       | 327/1261 [00:45<01:55,  8.09it/s]
#  26%|██▌       | 328/1261 [00:45<01:51,  8.35it/s]
#  26%|██▌       | 329/1261 [00:45<01:49,  8.52it/s]
#  26%|██▌       | 330/1261 [00:45<01:51,  8.37it/s]
#  26%|██▌       | 331/1261 [00:45<01:50,  8.39it/s]
#  26%|██▋       | 332/1261 [00:46<01:48,  8.57it/s]
#  26%|██▋       | 333/1261 [00:46<01:46,  8.72it/s]
#  26%|██▋       | 334/1261 [00:46<01:47,  8.59it/s]
#  27%|██▋       | 335/1261 [00:46<01:46,  8.69it/s]
#  27%|██▋       | 336/1261 [00:46<01:48,  8.50it/s]
#  27%|██▋       | 337/1261 [00:46<01:49,  8.44it/s]
#  27%|██▋       | 338/1261 [00:46<01:51,  8.28it/s]
#  27%|██▋       | 339/1261 [00:46<01:52,  8.16it/s]
#  27%|██▋       | 340/1261 [00:46<01:49,  8.42it/s]
#  27%|██▋       | 341/1261 [00:47<01:47,  8.58it/s]
#  27%|██▋       | 342/1261 [00:47<01:47,  8.51it/s]
#  27%|██▋       | 343/1261 [00:47<01:51,  8.22it/s]
#  27%|██▋       | 344/1261 [00:47<01:52,  8.18it/s]
#  27%|██▋       | 345/1261 [00:47<01:53,  8.10it/s]
#  27%|██▋       | 346/1261 [00:47<01:59,  7.66it/s]
#  28%|██▊       | 347/1261 [00:47<01:56,  7.88it/s]
#  28%|██▊       | 348/1261 [00:47<01:51,  8.21it/s]
#  28%|██▊       | 349/1261 [00:48<01:48,  8.38it/s]
#  28%|██▊       | 350/1261 [00:48<01:53,  8.01it/s]
#  28%|██▊       | 351/1261 [00:48<01:54,  7.97it/s]
#  28%|██▊       | 352/1261 [00:48<01:51,  8.17it/s]
#  28%|██▊       | 353/1261 [00:48<01:49,  8.28it/s]
#  28%|██▊       | 354/1261 [00:48<01:49,  8.30it/s]
#  28%|██▊       | 355/1261 [00:48<01:47,  8.44it/s]
#  28%|██▊       | 356/1261 [00:48<01:45,  8.59it/s]
#  28%|██▊       | 357/1261 [00:49<01:43,  8.73it/s]
#  28%|██▊       | 358/1261 [00:49<01:45,  8.57it/s]
#  28%|██▊       | 359/1261 [00:49<01:44,  8.66it/s]
#  29%|██▊       | 360/1261 [00:49<01:42,  8.80it/s]
#  29%|██▊       | 361/1261 [00:49<01:41,  8.90it/s]
#  29%|██▊       | 362/1261 [00:49<01:42,  8.75it/s]
#  29%|██▉       | 363/1261 [00:49<01:41,  8.82it/s]
#  29%|██▉       | 364/1261 [00:49<01:40,  8.94it/s]
#  29%|██▉       | 365/1261 [00:49<01:40,  8.95it/s]
#  29%|██▉       | 366/1261 [00:50<01:43,  8.68it/s]
#  29%|██▉       | 367/1261 [00:50<01:41,  8.78it/s]
#  29%|██▉       | 368/1261 [00:50<01:40,  8.86it/s]
#  29%|██▉       | 369/1261 [00:50<01:39,  8.96it/s]
#  29%|██▉       | 370/1261 [00:50<01:41,  8.77it/s]
#  29%|██▉       | 371/1261 [00:50<01:41,  8.74it/s]
#  30%|██▉       | 372/1261 [00:50<01:41,  8.78it/s]
#  30%|██▉       | 373/1261 [00:50<01:40,  8.84it/s]
#  30%|██▉       | 374/1261 [00:50<01:42,  8.68it/s]
#  30%|██▉       | 375/1261 [00:51<01:40,  8.77it/s]
#  30%|██▉       | 376/1261 [00:51<01:41,  8.75it/s]
#  30%|██▉       | 377/1261 [00:51<01:40,  8.80it/s]
#  30%|██▉       | 378/1261 [00:51<01:44,  8.43it/s]
#  30%|███       | 379/1261 [00:51<01:42,  8.58it/s]
#  30%|███       | 380/1261 [00:51<01:40,  8.74it/s]
#  30%|███       | 381/1261 [00:51<01:39,  8.82it/s]
#  30%|███       | 382/1261 [00:51<01:45,  8.33it/s]
#  30%|███       | 383/1261 [00:52<01:48,  8.12it/s]
#  30%|███       | 384/1261 [00:52<01:45,  8.29it/s]
#  31%|███       | 385/1261 [00:52<01:42,  8.51it/s]
#  31%|███       | 386/1261 [00:52<01:43,  8.42it/s]
#  31%|███       | 387/1261 [00:52<01:45,  8.29it/s]
#  31%|███       | 388/1261 [00:52<01:46,  8.23it/s]
#  31%|███       | 389/1261 [00:52<01:47,  8.13it/s]
#  31%|███       | 390/1261 [00:52<01:47,  8.13it/s]
#  31%|███       | 391/1261 [00:52<01:44,  8.35it/s]
#  31%|███       | 392/1261 [00:53<01:45,  8.27it/s]
#  31%|███       | 393/1261 [00:53<01:48,  7.97it/s]
#  31%|███       | 394/1261 [00:53<01:52,  7.69it/s]
#  31%|███▏      | 395/1261 [00:53<01:50,  7.86it/s]
#  31%|███▏      | 396/1261 [00:53<01:48,  7.99it/s]
#  31%|███▏      | 397/1261 [00:53<01:47,  8.07it/s]
#  32%|███▏      | 398/1261 [00:53<01:48,  7.97it/s]
#  32%|███▏      | 399/1261 [00:53<01:48,  7.96it/s]
#  32%|███▏      | 400/1261 [00:54<01:50,  7.81it/s]
#  32%|███▏      | 401/1261 [00:54<01:53,  7.55it/s]
#  32%|███▏      | 402/1261 [00:54<01:53,  7.60it/s]
#  32%|███▏      | 403/1261 [00:54<01:51,  7.67it/s]
#  32%|███▏      | 404/1261 [00:54<01:52,  7.64it/s]
#  32%|███▏      | 405/1261 [00:54<01:50,  7.76it/s]
#  32%|███▏      | 406/1261 [00:54<01:50,  7.74it/s]
#  32%|███▏      | 407/1261 [00:55<01:48,  7.87it/s]
#  32%|███▏      | 408/1261 [00:55<01:46,  8.04it/s]
#  32%|███▏      | 409/1261 [00:55<01:44,  8.13it/s]
#  33%|███▎      | 410/1261 [00:55<01:46,  8.02it/s]
#  33%|███▎      | 411/1261 [00:55<01:45,  8.07it/s]
#  33%|███▎      | 412/1261 [00:55<01:43,  8.22it/s]
#  33%|███▎      | 413/1261 [00:55<01:40,  8.40it/s]
#  33%|███▎      | 414/1261 [00:55<01:41,  8.32it/s]
#  33%|███▎      | 415/1261 [00:55<01:39,  8.48it/s]
#  33%|███▎      | 416/1261 [00:56<01:41,  8.35it/s]
#  33%|███▎      | 417/1261 [00:56<01:41,  8.34it/s]
#  33%|███▎      | 418/1261 [00:56<01:43,  8.13it/s]
#  33%|███▎      | 419/1261 [00:56<01:43,  8.13it/s]
#  33%|███▎      | 420/1261 [00:56<01:42,  8.24it/s]
#  33%|███▎      | 421/1261 [00:56<01:41,  8.29it/s]
#  33%|███▎      | 422/1261 [00:56<01:43,  8.12it/s]
#  34%|███▎      | 423/1261 [00:56<01:41,  8.28it/s]
#  34%|███▎      | 424/1261 [00:57<01:38,  8.52it/s]
#  34%|███▎      | 425/1261 [00:57<01:35,  8.73it/s]
#  34%|███▍      | 426/1261 [00:57<01:37,  8.54it/s]
#  34%|███▍      | 427/1261 [00:57<01:36,  8.61it/s]
#  34%|███▍      | 428/1261 [00:57<01:38,  8.46it/s]
#  34%|███▍      | 429/1261 [00:57<01:39,  8.40it/s]
#  34%|███▍      | 430/1261 [00:57<01:43,  8.04it/s]
#  34%|███▍      | 431/1261 [00:57<01:40,  8.23it/s]
#  34%|███▍      | 432/1261 [00:58<01:39,  8.35it/s]
#  34%|███▍      | 433/1261 [00:58<01:38,  8.43it/s]
#  34%|███▍      | 434/1261 [00:58<01:38,  8.40it/s]
#  34%|███▍      | 435/1261 [00:58<01:36,  8.54it/s]
#  35%|███▍      | 436/1261 [00:58<01:34,  8.70it/s]
#  35%|███▍      | 437/1261 [00:58<01:34,  8.70it/s]
#  35%|███▍      | 438/1261 [00:58<01:36,  8.53it/s]
#  35%|███▍      | 439/1261 [00:58<01:35,  8.58it/s]
#  35%|███▍      | 440/1261 [00:58<01:34,  8.70it/s]
#  35%|███▍      | 441/1261 [00:59<01:33,  8.75it/s]
#  35%|███▌      | 442/1261 [00:59<01:35,  8.60it/s]
#  35%|███▌      | 443/1261 [00:59<01:34,  8.69it/s]
#  35%|███▌      | 444/1261 [00:59<01:33,  8.78it/s]
#  35%|███▌      | 445/1261 [00:59<01:34,  8.65it/s]
#  35%|███▌      | 446/1261 [00:59<01:37,  8.32it/s]
#  35%|███▌      | 447/1261 [00:59<01:37,  8.36it/s]
#  36%|███▌      | 448/1261 [00:59<01:35,  8.50it/s]
#  36%|███▌      | 449/1261 [01:00<01:34,  8.55it/s]
#  36%|███▌      | 450/1261 [01:00<01:35,  8.49it/s]
#  36%|███▌      | 451/1261 [01:00<01:33,  8.62it/s]
#  36%|███▌      | 452/1261 [01:00<01:32,  8.74it/s]
#  36%|███▌      | 453/1261 [01:00<01:31,  8.82it/s]
#  36%|███▌      | 454/1261 [01:00<01:33,  8.59it/s]
#  36%|███▌      | 455/1261 [01:00<01:32,  8.69it/s]
#  36%|███▌      | 456/1261 [01:00<01:32,  8.72it/s]
#  36%|███▌      | 457/1261 [01:00<01:32,  8.66it/s]
#  36%|███▋      | 458/1261 [01:01<01:41,  7.89it/s]
#  36%|███▋      | 459/1261 [01:01<01:40,  7.95it/s]
#  36%|███▋      | 460/1261 [01:01<01:38,  8.12it/s]
#  37%|███▋      | 461/1261 [01:01<01:35,  8.37it/s]
#  37%|███▋      | 462/1261 [01:01<01:35,  8.33it/s]
#  37%|███▋      | 463/1261 [01:01<01:34,  8.48it/s]
#  37%|███▋      | 464/1261 [01:01<01:33,  8.57it/s]
#  37%|███▋      | 465/1261 [01:01<01:33,  8.47it/s]
#  37%|███▋      | 466/1261 [01:02<01:39,  7.99it/s]
#  37%|███▋      | 467/1261 [01:02<01:39,  7.99it/s]
#  37%|███▋      | 468/1261 [01:02<01:38,  8.08it/s]
#  37%|███▋      | 469/1261 [01:02<01:36,  8.20it/s]
#  37%|███▋      | 470/1261 [01:02<01:37,  8.09it/s]
#  37%|███▋      | 471/1261 [01:02<01:38,  7.99it/s]
#  37%|███▋      | 472/1261 [01:02<01:41,  7.79it/s]
#  38%|███▊      | 473/1261 [01:02<01:43,  7.59it/s]
#  38%|███▊      | 474/1261 [01:03<01:45,  7.47it/s]
#  38%|███▊      | 475/1261 [01:03<01:44,  7.50it/s]
#  38%|███▊      | 476/1261 [01:03<01:46,  7.36it/s]
#  38%|███▊      | 477/1261 [01:03<01:50,  7.09it/s]
#  38%|███▊      | 478/1261 [01:03<01:53,  6.90it/s]
#  38%|███▊      | 479/1261 [01:03<01:52,  6.96it/s]
#  38%|███▊      | 480/1261 [01:03<01:51,  7.01it/s]
#  38%|███▊      | 481/1261 [01:04<01:51,  6.97it/s]
#  38%|███▊      | 482/1261 [01:04<01:50,  7.02it/s]
#  38%|███▊      | 483/1261 [01:04<01:48,  7.19it/s]
#  38%|███▊      | 484/1261 [01:04<01:47,  7.24it/s]
#  38%|███▊      | 485/1261 [01:04<01:47,  7.20it/s]
#  39%|███▊      | 486/1261 [01:04<01:50,  7.04it/s]
#  39%|███▊      | 487/1261 [01:04<01:47,  7.18it/s]
#  39%|███▊      | 488/1261 [01:05<01:45,  7.35it/s]
#  39%|███▉      | 489/1261 [01:05<01:42,  7.52it/s]
#  39%|███▉      | 490/1261 [01:05<01:46,  7.23it/s]
#  39%|███▉      | 491/1261 [01:05<01:46,  7.21it/s]
#  39%|███▉      | 492/1261 [01:05<01:45,  7.32it/s]
#  39%|███▉      | 493/1261 [01:05<01:45,  7.29it/s]
#  39%|███▉      | 494/1261 [01:05<01:56,  6.59it/s]
#  39%|███▉      | 495/1261 [01:06<01:53,  6.73it/s]
#  39%|███▉      | 496/1261 [01:06<01:51,  6.87it/s]
#  39%|███▉      | 497/1261 [01:06<01:50,  6.90it/s]
#  39%|███▉      | 498/1261 [01:06<01:54,  6.64it/s]
#  40%|███▉      | 499/1261 [01:06<01:52,  6.76it/s]
#  40%|███▉      | 500/1261 [01:06<01:53,  6.69it/s]
#  40%|███▉      | 501/1261 [01:06<01:53,  6.71it/s]
#  40%|███▉      | 502/1261 [01:07<01:52,  6.74it/s]
#  40%|███▉      | 503/1261 [01:07<01:50,  6.87it/s]
#  40%|███▉      | 504/1261 [01:07<01:46,  7.11it/s]
#  40%|████      | 505/1261 [01:07<01:44,  7.23it/s]
#  40%|████      | 506/1261 [01:07<01:44,  7.22it/s]
#  40%|████      | 507/1261 [01:07<01:43,  7.27it/s]
#  40%|████      | 508/1261 [01:07<01:42,  7.38it/s]
#  40%|████      | 509/1261 [01:08<01:41,  7.43it/s]
#  40%|████      | 510/1261 [01:08<01:42,  7.36it/s]
#  41%|████      | 511/1261 [01:08<01:40,  7.49it/s]
#  41%|████      | 512/1261 [01:08<01:37,  7.68it/s]
#  41%|████      | 513/1261 [01:08<01:35,  7.87it/s]
#  41%|████      | 514/1261 [01:08<01:36,  7.78it/s]
#  41%|████      | 515/1261 [01:08<01:36,  7.74it/s]
#  41%|████      | 516/1261 [01:08<01:34,  7.88it/s]
#  41%|████      | 517/1261 [01:09<01:32,  8.04it/s]
#  41%|████      | 518/1261 [01:09<01:31,  8.14it/s]
#  41%|████      | 519/1261 [01:09<01:29,  8.32it/s]
#  41%|████      | 520/1261 [01:09<01:26,  8.53it/s]
#  41%|████▏     | 521/1261 [01:09<01:25,  8.67it/s]
#  41%|████▏     | 522/1261 [01:09<01:27,  8.43it/s]
#  41%|████▏     | 523/1261 [01:09<01:27,  8.41it/s]
#  42%|████▏     | 524/1261 [01:09<01:25,  8.60it/s]
#  42%|████▏     | 525/1261 [01:09<01:25,  8.65it/s]
#  42%|████▏     | 526/1261 [01:10<01:26,  8.51it/s]
#  42%|████▏     | 527/1261 [01:10<01:24,  8.68it/s]
#  42%|████▏     | 528/1261 [01:10<01:24,  8.71it/s]
#  42%|████▏     | 529/1261 [01:10<01:25,  8.58it/s]
#  42%|████▏     | 530/1261 [01:10<01:30,  8.09it/s]
#  42%|████▏     | 531/1261 [01:10<01:31,  8.00it/s]
#  42%|████▏     | 532/1261 [01:10<01:28,  8.20it/s]
#  42%|████▏     | 533/1261 [01:10<01:27,  8.34it/s]
#  42%|████▏     | 534/1261 [01:11<01:31,  7.96it/s]
#  42%|████▏     | 535/1261 [01:11<01:30,  7.98it/s]
#  43%|████▎     | 536/1261 [01:11<01:29,  8.14it/s]
#  43%|████▎     | 537/1261 [01:11<01:26,  8.37it/s]
#  43%|████▎     | 538/1261 [01:11<01:28,  8.14it/s]
#  43%|████▎     | 539/1261 [01:11<01:26,  8.34it/s]
#  43%|████▎     | 540/1261 [01:11<01:25,  8.39it/s]
#  43%|████▎     | 541/1261 [01:11<01:26,  8.35it/s]
#  43%|████▎     | 542/1261 [01:12<01:30,  7.98it/s]
#  43%|████▎     | 543/1261 [01:12<01:36,  7.48it/s]
#  43%|████▎     | 544/1261 [01:12<01:36,  7.44it/s]
#  43%|████▎     | 545/1261 [01:12<01:36,  7.41it/s]
#  43%|████▎     | 546/1261 [01:12<01:39,  7.16it/s]
#  43%|████▎     | 547/1261 [01:12<01:40,  7.12it/s]
#  43%|████▎     | 548/1261 [01:12<01:40,  7.08it/s]
#  44%|████▎     | 549/1261 [01:13<01:39,  7.16it/s]
#  44%|████▎     | 550/1261 [01:13<01:37,  7.32it/s]
#  44%|████▎     | 551/1261 [01:13<01:35,  7.40it/s]
#  44%|████▍     | 552/1261 [01:13<01:36,  7.35it/s]
#  44%|████▍     | 553/1261 [01:13<01:36,  7.31it/s]
#  44%|████▍     | 554/1261 [01:13<01:39,  7.12it/s]
#  44%|████▍     | 555/1261 [01:13<01:40,  7.03it/s]
#  44%|████▍     | 556/1261 [01:14<01:40,  7.02it/s]
#  44%|████▍     | 557/1261 [01:14<01:38,  7.14it/s]
#  44%|████▍     | 558/1261 [01:14<01:36,  7.28it/s]
#  44%|████▍     | 559/1261 [01:14<01:35,  7.36it/s]
#  44%|████▍     | 560/1261 [01:14<01:36,  7.26it/s]
#  44%|████▍     | 561/1261 [01:14<01:35,  7.33it/s]
#  45%|████▍     | 562/1261 [01:14<01:34,  7.41it/s]
#  45%|████▍     | 563/1261 [01:14<01:34,  7.39it/s]
#  45%|████▍     | 564/1261 [01:15<01:34,  7.36it/s]
#  45%|████▍     | 565/1261 [01:15<01:31,  7.63it/s]
#  45%|████▍     | 566/1261 [01:15<01:26,  7.99it/s]
#  45%|████▍     | 567/1261 [01:15<01:24,  8.24it/s]
#  45%|████▌     | 568/1261 [01:15<01:24,  8.17it/s]
#  45%|████▌     | 569/1261 [01:15<01:26,  7.99it/s]
#  45%|████▌     | 570/1261 [01:15<01:24,  8.22it/s]
#  45%|████▌     | 571/1261 [01:15<01:22,  8.35it/s]
#  45%|████▌     | 572/1261 [01:16<01:24,  8.17it/s]
#  45%|████▌     | 573/1261 [01:16<01:27,  7.90it/s]
#  46%|████▌     | 574/1261 [01:16<01:27,  7.88it/s]
#  46%|████▌     | 575/1261 [01:16<01:24,  8.14it/s]
#  46%|████▌     | 576/1261 [01:16<01:23,  8.22it/s]
#  46%|████▌     | 577/1261 [01:16<01:22,  8.29it/s]
#  46%|████▌     | 578/1261 [01:16<01:20,  8.50it/s]
#  46%|████▌     | 579/1261 [01:16<01:20,  8.50it/s]
#  46%|████▌     | 580/1261 [01:17<01:24,  8.02it/s]
#  46%|████▌     | 581/1261 [01:17<01:23,  8.12it/s]
#  46%|████▌     | 582/1261 [01:17<01:21,  8.36it/s]
#  46%|████▌     | 583/1261 [01:17<01:19,  8.50it/s]
#  46%|████▋     | 584/1261 [01:17<01:22,  8.21it/s]
#  46%|████▋     | 585/1261 [01:17<01:25,  7.92it/s]
#  46%|████▋     | 586/1261 [01:17<01:24,  7.97it/s]
#  47%|████▋     | 587/1261 [01:17<01:23,  8.11it/s]
#  47%|████▋     | 588/1261 [01:18<01:23,  8.07it/s]
#  47%|████▋     | 589/1261 [01:18<01:21,  8.25it/s]
#  47%|████▋     | 590/1261 [01:18<01:18,  8.50it/s]
#  47%|████▋     | 591/1261 [01:18<01:17,  8.59it/s]
#  47%|████▋     | 592/1261 [01:18<01:20,  8.27it/s]
#  47%|████▋     | 593/1261 [01:18<01:19,  8.40it/s]
#  47%|████▋     | 594/1261 [01:18<01:18,  8.52it/s]
#  47%|████▋     | 595/1261 [01:18<01:22,  8.10it/s]
#  47%|████▋     | 596/1261 [01:18<01:25,  7.82it/s]
#  47%|████▋     | 597/1261 [01:19<01:24,  7.89it/s]
#  47%|████▋     | 598/1261 [01:19<01:23,  7.98it/s]
#  48%|████▊     | 599/1261 [01:19<01:20,  8.21it/s]
#  48%|████▊     | 600/1261 [01:19<01:23,  7.91it/s]
#  48%|████▊     | 601/1261 [01:19<01:23,  7.90it/s]
#  48%|████▊     | 602/1261 [01:19<01:21,  8.10it/s]
#  48%|████▊     | 603/1261 [01:19<01:20,  8.14it/s]
#  48%|████▊     | 604/1261 [01:19<01:22,  7.97it/s]
#  48%|████▊     | 605/1261 [01:20<01:22,  7.98it/s]
#  48%|████▊     | 606/1261 [01:20<01:21,  8.06it/s]
#  48%|████▊     | 607/1261 [01:20<01:20,  8.13it/s]
#  48%|████▊     | 608/1261 [01:20<01:24,  7.77it/s]
#  48%|████▊     | 609/1261 [01:20<01:26,  7.57it/s]
#  48%|████▊     | 610/1261 [01:20<01:25,  7.58it/s]
#  48%|████▊     | 611/1261 [01:20<01:22,  7.87it/s]
#  49%|████▊     | 612/1261 [01:21<01:21,  7.92it/s]
#  49%|████▊     | 613/1261 [01:21<01:17,  8.39it/s]
#  49%|████▊     | 614/1261 [01:21<01:15,  8.52it/s]
#  49%|████▉     | 616/1261 [01:21<01:13,  8.73it/s]
#  49%|████▉     | 617/1261 [01:21<01:14,  8.66it/s]
#  49%|████▉     | 618/1261 [01:21<01:12,  8.89it/s]
#  49%|████▉     | 619/1261 [01:21<01:10,  9.08it/s]
#  49%|████▉     | 620/1261 [01:21<01:13,  8.67it/s]
#  49%|████▉     | 621/1261 [01:22<01:17,  8.21it/s]
#  49%|████▉     | 622/1261 [01:22<01:16,  8.38it/s]
#  49%|████▉     | 623/1261 [01:22<01:14,  8.59it/s]
#  49%|████▉     | 624/1261 [01:22<01:15,  8.45it/s]
#  50%|████▉     | 625/1261 [01:22<01:15,  8.47it/s]
#  50%|████▉     | 626/1261 [01:22<01:14,  8.50it/s]
#  50%|████▉     | 627/1261 [01:22<01:12,  8.69it/s]
#  50%|████▉     | 628/1261 [01:22<01:14,  8.48it/s]
#  50%|████▉     | 629/1261 [01:22<01:14,  8.47it/s]
#  50%|████▉     | 630/1261 [01:23<01:13,  8.64it/s]
#  50%|█████     | 631/1261 [01:23<01:11,  8.76it/s]
#  50%|█████     | 632/1261 [01:23<01:13,  8.59it/s]
#  50%|█████     | 633/1261 [01:23<01:12,  8.70it/s]
#  50%|█████     | 634/1261 [01:23<01:10,  8.84it/s]
#  50%|█████     | 635/1261 [01:23<01:10,  8.93it/s]
#  50%|█████     | 636/1261 [01:23<01:11,  8.70it/s]
#  51%|█████     | 637/1261 [01:23<01:10,  8.85it/s]
#  51%|█████     | 638/1261 [01:23<01:09,  8.97it/s]
#  51%|█████     | 639/1261 [01:24<01:09,  9.00it/s]
#  51%|█████     | 640/1261 [01:24<01:10,  8.79it/s]
#  51%|█████     | 641/1261 [01:24<01:11,  8.72it/s]
#  51%|█████     | 642/1261 [01:24<01:10,  8.73it/s]
#  51%|█████     | 643/1261 [01:24<01:10,  8.80it/s]
#  51%|█████     | 644/1261 [01:24<01:14,  8.27it/s]
#  51%|█████     | 645/1261 [01:24<01:13,  8.40it/s]
#  51%|█████     | 646/1261 [01:24<01:11,  8.59it/s]
#  51%|█████▏    | 647/1261 [01:25<01:11,  8.61it/s]
#  51%|█████▏    | 648/1261 [01:25<01:10,  8.72it/s]
#  51%|█████▏    | 649/1261 [01:25<01:08,  8.88it/s]
#  52%|█████▏    | 650/1261 [01:25<01:08,  8.95it/s]
#  52%|█████▏    | 651/1261 [01:25<01:10,  8.61it/s]
#  52%|█████▏    | 652/1261 [01:25<01:10,  8.65it/s]
#  52%|█████▏    | 653/1261 [01:25<01:09,  8.77it/s]
#  52%|█████▏    | 654/1261 [01:25<01:08,  8.85it/s]
#  52%|█████▏    | 655/1261 [01:25<01:12,  8.42it/s]
#  52%|█████▏    | 656/1261 [01:26<01:11,  8.50it/s]
#  52%|█████▏    | 657/1261 [01:26<01:10,  8.52it/s]
#  52%|█████▏    | 658/1261 [01:26<01:10,  8.55it/s]
#  52%|█████▏    | 659/1261 [01:26<01:10,  8.58it/s]
#  52%|█████▏    | 660/1261 [01:26<01:11,  8.43it/s]
#  52%|█████▏    | 661/1261 [01:26<01:15,  7.99it/s]
#  52%|█████▏    | 662/1261 [01:26<01:15,  7.91it/s]
#  53%|█████▎    | 663/1261 [01:26<01:15,  7.95it/s]
#  53%|█████▎    | 664/1261 [01:27<01:15,  7.86it/s]
#  53%|█████▎    | 665/1261 [01:27<01:16,  7.75it/s]
#  53%|█████▎    | 666/1261 [01:27<01:15,  7.92it/s]
#  53%|█████▎    | 667/1261 [01:27<01:14,  7.97it/s]
#  53%|█████▎    | 668/1261 [01:27<01:14,  7.95it/s]
#  53%|█████▎    | 669/1261 [01:27<01:13,  8.09it/s]
#  53%|█████▎    | 670/1261 [01:27<01:13,  8.03it/s]
#  53%|█████▎    | 671/1261 [01:27<01:11,  8.20it/s]
#  53%|█████▎    | 672/1261 [01:28<01:11,  8.24it/s]
#  53%|█████▎    | 673/1261 [01:28<01:11,  8.18it/s]
#  53%|█████▎    | 674/1261 [01:28<01:11,  8.22it/s]
#  54%|█████▎    | 675/1261 [01:28<01:11,  8.16it/s]
#  54%|█████▎    | 676/1261 [01:28<01:10,  8.34it/s]
#  54%|█████▎    | 677/1261 [01:28<01:08,  8.55it/s]
#  54%|█████▍    | 678/1261 [01:28<01:07,  8.67it/s]
#  54%|█████▍    | 679/1261 [01:28<01:09,  8.38it/s]
#  54%|█████▍    | 680/1261 [01:28<01:09,  8.39it/s]
#  54%|█████▍    | 681/1261 [01:29<01:07,  8.54it/s]
#  54%|█████▍    | 682/1261 [01:29<01:06,  8.70it/s]
#  54%|█████▍    | 683/1261 [01:29<01:08,  8.49it/s]
#  54%|█████▍    | 684/1261 [01:29<01:08,  8.44it/s]
#  54%|█████▍    | 685/1261 [01:29<01:07,  8.57it/s]
#  54%|█████▍    | 686/1261 [01:29<01:06,  8.70it/s]
#  54%|█████▍    | 687/1261 [01:29<01:07,  8.56it/s]
#  55%|█████▍    | 688/1261 [01:29<01:05,  8.70it/s]
#  55%|█████▍    | 689/1261 [01:30<01:05,  8.67it/s]
#  55%|█████▍    | 690/1261 [01:30<01:06,  8.56it/s]
#  55%|█████▍    | 691/1261 [01:30<01:05,  8.67it/s]
#  55%|█████▍    | 692/1261 [01:30<01:05,  8.70it/s]
#  55%|█████▍    | 693/1261 [01:30<01:04,  8.79it/s]
#  55%|█████▌    | 694/1261 [01:30<01:05,  8.60it/s]
#  55%|█████▌    | 695/1261 [01:30<01:04,  8.71it/s]
#  55%|█████▌    | 696/1261 [01:30<01:03,  8.84it/s]
#  55%|█████▌    | 697/1261 [01:30<01:03,  8.94it/s]
#  55%|█████▌    | 698/1261 [01:31<01:05,  8.53it/s]
#  55%|█████▌    | 699/1261 [01:31<01:04,  8.67it/s]
#  56%|█████▌    | 700/1261 [01:31<01:03,  8.82it/s]
#  56%|█████▌    | 701/1261 [01:31<01:04,  8.66it/s]
#  56%|█████▌    | 702/1261 [01:31<01:11,  7.83it/s]
#  56%|█████▌    | 703/1261 [01:31<01:10,  7.91it/s]
#  56%|█████▌    | 704/1261 [01:31<01:07,  8.23it/s]
#  56%|█████▌    | 705/1261 [01:31<01:05,  8.46it/s]
#  56%|█████▌    | 706/1261 [01:32<01:08,  8.06it/s]
#  56%|█████▌    | 707/1261 [01:32<01:08,  8.07it/s]
#  56%|█████▌    | 708/1261 [01:32<01:07,  8.24it/s]
#  56%|█████▌    | 709/1261 [01:32<01:05,  8.49it/s]
#  56%|█████▋    | 710/1261 [01:32<01:05,  8.45it/s]
#  56%|█████▋    | 711/1261 [01:32<01:05,  8.43it/s]
#  56%|█████▋    | 712/1261 [01:32<01:05,  8.37it/s]
#  57%|█████▋    | 713/1261 [01:32<01:04,  8.47it/s]
#  57%|█████▋    | 714/1261 [01:32<01:05,  8.41it/s]
#  57%|█████▋    | 715/1261 [01:33<01:03,  8.57it/s]
#  57%|█████▋    | 716/1261 [01:33<01:02,  8.69it/s]
#  57%|█████▋    | 717/1261 [01:33<01:01,  8.85it/s]
#  57%|█████▋    | 718/1261 [01:33<01:02,  8.71it/s]
#  57%|█████▋    | 719/1261 [01:33<01:01,  8.80it/s]
#  57%|█████▋    | 720/1261 [01:33<01:00,  8.91it/s]
#  57%|█████▋    | 721/1261 [01:33<00:59,  9.00it/s]
#  57%|█████▋    | 722/1261 [01:33<01:01,  8.78it/s]
#  57%|█████▋    | 723/1261 [01:34<01:00,  8.85it/s]
#  57%|█████▋    | 724/1261 [01:34<00:59,  8.95it/s]
#  57%|█████▋    | 725/1261 [01:34<00:59,  9.07it/s]
#  58%|█████▊    | 726/1261 [01:34<01:00,  8.88it/s]
#  58%|█████▊    | 727/1261 [01:34<01:00,  8.88it/s]
#  58%|█████▊    | 728/1261 [01:34<00:59,  9.01it/s]
#  58%|█████▊    | 729/1261 [01:34<00:58,  9.03it/s]
#  58%|█████▊    | 730/1261 [01:34<01:00,  8.73it/s]
#  58%|█████▊    | 731/1261 [01:34<01:00,  8.82it/s]
#  58%|█████▊    | 732/1261 [01:35<00:59,  8.96it/s]
#  58%|█████▊    | 733/1261 [01:35<00:58,  9.03it/s]
#  58%|█████▊    | 734/1261 [01:35<00:59,  8.84it/s]
#  58%|█████▊    | 735/1261 [01:35<00:59,  8.91it/s]
#  58%|█████▊    | 736/1261 [01:35<00:58,  9.02it/s]
#  58%|█████▊    | 737/1261 [01:35<00:57,  9.09it/s]
#  59%|█████▊    | 738/1261 [01:35<01:01,  8.56it/s]
#  59%|█████▊    | 739/1261 [01:35<01:02,  8.39it/s]
#  59%|█████▊    | 740/1261 [01:35<01:01,  8.48it/s]
#  59%|█████▉    | 741/1261 [01:36<01:00,  8.59it/s]
#  59%|█████▉    | 742/1261 [01:36<01:00,  8.52it/s]
#  59%|█████▉    | 743/1261 [01:36<01:00,  8.58it/s]
#  59%|█████▉    | 744/1261 [01:36<00:58,  8.76it/s]
#  59%|█████▉    | 745/1261 [01:36<00:58,  8.78it/s]
#  59%|█████▉    | 746/1261 [01:36<00:59,  8.66it/s]
#  59%|█████▉    | 747/1261 [01:36<00:59,  8.70it/s]
#  59%|█████▉    | 748/1261 [01:36<00:58,  8.73it/s]
#  59%|█████▉    | 749/1261 [01:36<00:57,  8.85it/s]
#  59%|█████▉    | 750/1261 [01:37<00:59,  8.63it/s]
#  60%|█████▉    | 751/1261 [01:37<00:58,  8.74it/s]
#  60%|█████▉    | 752/1261 [01:37<00:58,  8.77it/s]
#  60%|█████▉    | 753/1261 [01:37<00:58,  8.72it/s]
#  60%|█████▉    | 754/1261 [01:37<00:59,  8.53it/s]
#  60%|█████▉    | 755/1261 [01:37<00:58,  8.69it/s]
#  60%|█████▉    | 756/1261 [01:37<00:58,  8.66it/s]
#  60%|██████    | 757/1261 [01:37<00:58,  8.56it/s]
#  60%|██████    | 758/1261 [01:38<01:01,  8.23it/s]
#  60%|██████    | 759/1261 [01:38<01:01,  8.16it/s]
#  60%|██████    | 760/1261 [01:38<01:01,  8.16it/s]
#  60%|██████    | 761/1261 [01:38<01:02,  7.96it/s]
#  60%|██████    | 762/1261 [01:38<01:03,  7.83it/s]
#  61%|██████    | 763/1261 [01:38<01:03,  7.90it/s]
#  61%|██████    | 764/1261 [01:38<01:04,  7.74it/s]
#  61%|██████    | 765/1261 [01:38<01:02,  7.92it/s]
#  61%|██████    | 766/1261 [01:39<01:04,  7.72it/s]
#  61%|██████    | 767/1261 [01:39<01:03,  7.80it/s]
#  61%|██████    | 768/1261 [01:39<01:02,  7.87it/s]
#  61%|██████    | 769/1261 [01:39<01:02,  7.91it/s]
#  61%|██████    | 770/1261 [01:39<01:02,  7.82it/s]
#  61%|██████    | 771/1261 [01:39<01:02,  7.85it/s]
#  61%|██████    | 772/1261 [01:39<01:01,  7.92it/s]
#  61%|██████▏   | 773/1261 [01:39<01:01,  7.97it/s]
#  61%|██████▏   | 774/1261 [01:40<01:02,  7.79it/s]
#  61%|██████▏   | 775/1261 [01:40<01:01,  7.85it/s]
#  62%|██████▏   | 776/1261 [01:40<01:00,  8.00it/s]
#  62%|██████▏   | 777/1261 [01:40<00:58,  8.22it/s]
#  62%|██████▏   | 778/1261 [01:40<01:00,  8.01it/s]
#  62%|██████▏   | 779/1261 [01:40<00:59,  8.07it/s]
#  62%|██████▏   | 780/1261 [01:40<00:59,  8.10it/s]
#  62%|██████▏   | 781/1261 [01:40<00:58,  8.16it/s]
#  62%|██████▏   | 782/1261 [01:41<01:00,  7.98it/s]
#  62%|██████▏   | 783/1261 [01:41<00:59,  8.05it/s]
#  62%|██████▏   | 784/1261 [01:41<00:59,  8.07it/s]
#  62%|██████▏   | 785/1261 [01:41<00:58,  8.16it/s]
#  62%|██████▏   | 786/1261 [01:41<00:59,  8.01it/s]
#  62%|██████▏   | 787/1261 [01:41<00:56,  8.35it/s]
#  62%|██████▏   | 788/1261 [01:41<00:55,  8.52it/s]
#  63%|██████▎   | 789/1261 [01:41<00:55,  8.50it/s]
#  63%|██████▎   | 790/1261 [01:42<00:56,  8.34it/s]
#  63%|██████▎   | 791/1261 [01:42<00:56,  8.34it/s]
#  63%|██████▎   | 792/1261 [01:42<00:56,  8.24it/s]
#  63%|██████▎   | 793/1261 [01:42<00:58,  7.98it/s]
#  63%|██████▎   | 794/1261 [01:42<00:59,  7.90it/s]
#  63%|██████▎   | 795/1261 [01:42<01:00,  7.73it/s]
#  63%|██████▎   | 796/1261 [01:42<00:58,  8.01it/s]
#  63%|██████▎   | 797/1261 [01:42<00:55,  8.33it/s]
#  63%|██████▎   | 798/1261 [01:42<00:55,  8.34it/s]
#  63%|██████▎   | 799/1261 [01:43<00:54,  8.54it/s]
#  63%|██████▎   | 800/1261 [01:43<00:52,  8.73it/s]
#  64%|██████▎   | 801/1261 [01:43<00:52,  8.77it/s]
#  64%|██████▎   | 802/1261 [01:43<00:55,  8.27it/s]
#  64%|██████▎   | 803/1261 [01:43<00:55,  8.26it/s]
#  64%|██████▍   | 804/1261 [01:43<00:56,  8.11it/s]
#  64%|██████▍   | 805/1261 [01:43<00:55,  8.23it/s]
#  64%|██████▍   | 806/1261 [01:43<00:54,  8.28it/s]
#  64%|██████▍   | 807/1261 [01:44<00:53,  8.45it/s]
#  64%|██████▍   | 808/1261 [01:44<00:53,  8.47it/s]
#  64%|██████▍   | 809/1261 [01:44<00:52,  8.64it/s]
#  64%|██████▍   | 810/1261 [01:44<00:53,  8.47it/s]
#  64%|██████▍   | 811/1261 [01:44<00:52,  8.62it/s]
#  64%|██████▍   | 812/1261 [01:44<00:51,  8.67it/s]
#  64%|██████▍   | 813/1261 [01:44<00:52,  8.51it/s]
#  65%|██████▍   | 814/1261 [01:44<00:54,  8.16it/s]
#  65%|██████▍   | 815/1261 [01:45<00:54,  8.14it/s]
#  65%|██████▍   | 816/1261 [01:45<00:57,  7.74it/s]
#  65%|██████▍   | 817/1261 [01:45<00:57,  7.68it/s]
#  65%|██████▍   | 818/1261 [01:45<00:58,  7.60it/s]
#  65%|██████▍   | 819/1261 [01:45<00:56,  7.78it/s]
#  65%|██████▌   | 820/1261 [01:45<00:58,  7.60it/s]
#  65%|██████▌   | 821/1261 [01:45<00:59,  7.34it/s]
#  65%|██████▌   | 822/1261 [01:46<01:03,  6.95it/s]
#  65%|██████▌   | 823/1261 [01:46<01:01,  7.14it/s]
#  65%|██████▌   | 824/1261 [01:46<00:59,  7.39it/s]
#  65%|██████▌   | 825/1261 [01:46<00:58,  7.44it/s]
#  66%|██████▌   | 826/1261 [01:46<01:01,  7.10it/s]
#  66%|██████▌   | 827/1261 [01:46<01:01,  7.11it/s]
#  66%|██████▌   | 828/1261 [01:46<00:59,  7.32it/s]
#  66%|██████▌   | 829/1261 [01:46<00:58,  7.35it/s]
#  66%|██████▌   | 830/1261 [01:47<01:03,  6.76it/s]
#  66%|██████▌   | 831/1261 [01:47<01:02,  6.87it/s]
#  66%|██████▌   | 832/1261 [01:47<00:59,  7.22it/s]
#  66%|██████▌   | 833/1261 [01:47<00:57,  7.46it/s]
#  66%|██████▌   | 834/1261 [01:47<00:58,  7.27it/s]
#  66%|██████▌   | 835/1261 [01:47<00:59,  7.11it/s]
#  66%|██████▋   | 836/1261 [01:47<00:59,  7.17it/s]
#  66%|██████▋   | 837/1261 [01:48<00:59,  7.11it/s]
#  66%|██████▋   | 838/1261 [01:48<01:03,  6.63it/s]
#  67%|██████▋   | 839/1261 [01:48<01:01,  6.86it/s]
#  67%|██████▋   | 840/1261 [01:48<00:58,  7.22it/s]
#  67%|██████▋   | 841/1261 [01:48<00:57,  7.37it/s]
#  67%|██████▋   | 842/1261 [01:48<00:57,  7.28it/s]
#  67%|██████▋   | 843/1261 [01:48<00:57,  7.30it/s]
#  67%|██████▋   | 844/1261 [01:49<00:56,  7.40it/s]
#  67%|██████▋   | 845/1261 [01:49<00:55,  7.45it/s]
#  67%|██████▋   | 846/1261 [01:49<00:55,  7.45it/s]
#  67%|██████▋   | 847/1261 [01:49<00:54,  7.57it/s]
#  67%|██████▋   | 848/1261 [01:49<00:53,  7.66it/s]
#  67%|██████▋   | 849/1261 [01:49<00:53,  7.75it/s]
#  67%|██████▋   | 850/1261 [01:49<00:54,  7.58it/s]
#  67%|██████▋   | 851/1261 [01:49<00:53,  7.73it/s]
#  68%|██████▊   | 852/1261 [01:50<00:52,  7.84it/s]
#  68%|██████▊   | 853/1261 [01:50<00:51,  7.97it/s]
#  68%|██████▊   | 854/1261 [01:50<00:52,  7.82it/s]
#  68%|██████▊   | 855/1261 [01:50<00:51,  7.90it/s]
#  68%|██████▊   | 856/1261 [01:50<00:50,  7.98it/s]
#  68%|██████▊   | 857/1261 [01:50<00:50,  8.03it/s]
#  68%|██████▊   | 858/1261 [01:50<00:51,  7.83it/s]
#  68%|██████▊   | 859/1261 [01:50<00:51,  7.87it/s]
#  68%|██████▊   | 860/1261 [01:51<00:50,  7.94it/s]
#  68%|██████▊   | 861/1261 [01:51<00:50,  7.94it/s]
#  68%|██████▊   | 862/1261 [01:51<00:51,  7.81it/s]
#  68%|██████▊   | 863/1261 [01:51<00:50,  7.91it/s]
#  69%|██████▊   | 864/1261 [01:51<00:50,  7.86it/s]
#  69%|██████▊   | 865/1261 [01:51<00:49,  7.95it/s]
#  69%|██████▊   | 866/1261 [01:51<00:51,  7.60it/s]
#  69%|██████▉   | 867/1261 [01:52<00:53,  7.35it/s]
#  69%|██████▉   | 868/1261 [01:52<00:51,  7.61it/s]
#  69%|██████▉   | 869/1261 [01:52<00:50,  7.80it/s]
#  69%|██████▉   | 870/1261 [01:52<00:51,  7.63it/s]
#  69%|██████▉   | 871/1261 [01:52<00:51,  7.64it/s]
#  69%|██████▉   | 872/1261 [01:52<00:49,  7.79it/s]
#  69%|██████▉   | 873/1261 [01:52<00:49,  7.85it/s]
#  69%|██████▉   | 874/1261 [01:52<00:51,  7.56it/s]
#  69%|██████▉   | 875/1261 [01:53<00:51,  7.54it/s]
#  69%|██████▉   | 876/1261 [01:53<00:50,  7.56it/s]
#  70%|██████▉   | 877/1261 [01:53<00:50,  7.65it/s]
#  70%|██████▉   | 878/1261 [01:53<00:50,  7.54it/s]
#  70%|██████▉   | 879/1261 [01:53<00:50,  7.52it/s]
#  70%|██████▉   | 880/1261 [01:53<00:50,  7.59it/s]
#  70%|██████▉   | 881/1261 [01:53<00:49,  7.63it/s]
#  70%|██████▉   | 882/1261 [01:53<00:50,  7.50it/s]
#  70%|███████   | 883/1261 [01:54<00:50,  7.48it/s]
#  70%|███████   | 884/1261 [01:54<00:49,  7.56it/s]
#  70%|███████   | 885/1261 [01:54<00:49,  7.61it/s]
#  70%|███████   | 886/1261 [01:54<00:50,  7.49it/s]
#  70%|███████   | 887/1261 [01:54<00:48,  7.68it/s]
#  70%|███████   | 888/1261 [01:54<00:48,  7.76it/s]
#  70%|███████   | 889/1261 [01:54<00:47,  7.75it/s]
#  71%|███████   | 890/1261 [01:55<00:48,  7.67it/s]
#  71%|███████   | 891/1261 [01:55<00:47,  7.77it/s]
#  71%|███████   | 892/1261 [01:55<00:47,  7.78it/s]
#  71%|███████   | 893/1261 [01:55<00:46,  7.84it/s]
#  71%|███████   | 894/1261 [01:55<00:46,  7.87it/s]
#  71%|███████   | 895/1261 [01:55<00:45,  8.03it/s]
#  71%|███████   | 896/1261 [01:55<00:45,  8.10it/s]
#  71%|███████   | 897/1261 [01:55<00:44,  8.21it/s]
#  71%|███████   | 898/1261 [01:56<00:45,  7.97it/s]
#  71%|███████▏  | 899/1261 [01:56<00:46,  7.85it/s]
#  71%|███████▏  | 900/1261 [01:56<00:46,  7.78it/s]
#  71%|███████▏  | 901/1261 [01:56<00:46,  7.75it/s]
#  72%|███████▏  | 902/1261 [01:56<00:46,  7.72it/s]
#  72%|███████▏  | 903/1261 [01:56<00:46,  7.78it/s]
#  72%|███████▏  | 904/1261 [01:56<00:45,  7.81it/s]
#  72%|███████▏  | 905/1261 [01:56<00:44,  7.96it/s]
#  72%|███████▏  | 906/1261 [01:57<00:45,  7.83it/s]
#  72%|███████▏  | 907/1261 [01:57<00:45,  7.77it/s]
#  72%|███████▏  | 908/1261 [01:57<00:46,  7.54it/s]
#  72%|███████▏  | 909/1261 [01:57<00:48,  7.21it/s]
#  72%|███████▏  | 910/1261 [01:57<00:49,  7.06it/s]
#  72%|███████▏  | 911/1261 [01:57<00:48,  7.19it/s]
#  72%|███████▏  | 912/1261 [01:57<00:48,  7.26it/s]
#  72%|███████▏  | 913/1261 [01:58<00:47,  7.29it/s]
#  72%|███████▏  | 914/1261 [01:58<00:48,  7.20it/s]
#  73%|███████▎  | 915/1261 [01:58<00:47,  7.28it/s]
#  73%|███████▎  | 916/1261 [01:58<00:47,  7.34it/s]
#  73%|███████▎  | 917/1261 [01:58<00:46,  7.33it/s]
#  73%|███████▎  | 918/1261 [01:58<00:47,  7.22it/s]
#  73%|███████▎  | 919/1261 [01:58<00:46,  7.31it/s]
#  73%|███████▎  | 920/1261 [01:58<00:46,  7.35it/s]
#  73%|███████▎  | 921/1261 [01:59<00:46,  7.25it/s]
#  73%|███████▎  | 922/1261 [01:59<00:49,  6.84it/s]
#  73%|███████▎  | 923/1261 [01:59<00:49,  6.78it/s]
#  73%|███████▎  | 924/1261 [01:59<00:49,  6.85it/s]
#  73%|███████▎  | 925/1261 [01:59<00:47,  7.07it/s]
#  73%|███████▎  | 926/1261 [01:59<00:47,  7.04it/s]
#  74%|███████▎  | 927/1261 [01:59<00:47,  7.10it/s]
#  74%|███████▎  | 928/1261 [02:00<00:48,  6.93it/s]
#  74%|███████▎  | 929/1261 [02:00<00:47,  6.93it/s]
#  74%|███████▍  | 930/1261 [02:00<00:47,  6.97it/s]
#  74%|███████▍  | 931/1261 [02:00<00:47,  7.01it/s]
#  74%|███████▍  | 932/1261 [02:00<00:47,  6.99it/s]
#  74%|███████▍  | 933/1261 [02:00<00:47,  6.95it/s]
#  74%|███████▍  | 934/1261 [02:01<00:47,  6.94it/s]
#  74%|███████▍  | 935/1261 [02:01<00:45,  7.09it/s]
#  74%|███████▍  | 936/1261 [02:01<00:44,  7.25it/s]
#  74%|███████▍  | 937/1261 [02:01<00:44,  7.35it/s]
#  74%|███████▍  | 938/1261 [02:01<00:44,  7.28it/s]
#  74%|███████▍  | 939/1261 [02:01<00:43,  7.34it/s]
#  75%|███████▍  | 940/1261 [02:01<00:43,  7.42it/s]
#  75%|███████▍  | 941/1261 [02:01<00:42,  7.45it/s]
# ...
#  76%|███████▌  | 955/1261 [02:03<00:40,  7.52it/s]
#  76%|███████▌  | 956/1261 [02:03<00:40,  7.49it/s]
#  76%|███████▌  | 957/1261 [02:04<00:41,  7.25it/s]
#  76%|███████▌  | 958/1261 [02:04<00:43,  6.94it/s]
#  76%|███████▌  | 959/1261 [02:04<00:44,  6.78it/s]
#  76%|███████▌  | 960/1261 [02:04<00:44,  6.72it/s]
#  76%|███████▌  | 961/1261 [02:04<00:44,  6.67it/s]
#  76%|███████▋  | 962/1261 [02:04<00:45,  6.51it/s]
#  76%|███████▋  | 963/1261 [02:05<00:44,  6.70it/s]
#  76%|███████▋  | 964/1261 [02:05<00:43,  6.87it/s]
#  77%|███████▋  | 965/1261 [02:05<00:41,  7.16it/s]
#  77%|███████▋  | 966/1261 [02:05<00:39,  7.46it/s]
#  77%|███████▋  | 967/1261 [02:05<00:37,  7.86it/s]
#  77%|███████▋  | 968/1261 [02:05<00:38,  7.63it/s]
#  77%|███████▋  | 969/1261 [02:05<00:38,  7.59it/s]
#  77%|███████▋  | 970/1261 [02:05<00:36,  7.87it/s]
#  77%|███████▋  | 971/1261 [02:06<00:35,  8.16it/s]
#  77%|███████▋  | 972/1261 [02:06<00:37,  7.71it/s]
#  77%|███████▋  | 973/1261 [02:06<00:37,  7.65it/s]
#  77%|███████▋  | 974/1261 [02:06<00:36,  7.79it/s]
#  77%|███████▋  | 975/1261 [02:06<00:35,  8.04it/s]
#  77%|███████▋  | 976/1261 [02:06<00:35,  8.07it/s]
#  77%|███████▋  | 977/1261 [02:06<00:34,  8.20it/s]
#  78%|███████▊  | 978/1261 [02:06<00:34,  8.25it/s]
#  78%|███████▊  | 979/1261 [02:07<00:35,  7.91it/s]
#  78%|███████▊  | 980/1261 [02:07<00:37,  7.41it/s]
#  78%|███████▊  | 981/1261 [02:07<00:38,  7.29it/s]
#  78%|███████▊  | 982/1261 [02:07<00:39,  7.15it/s]
#  78%|███████▊  | 983/1261 [02:07<00:39,  7.11it/s]
#  78%|███████▊  | 984/1261 [02:07<00:39,  7.09it/s]
#  78%|███████▊  | 985/1261 [02:07<00:38,  7.13it/s]
#  78%|███████▊  | 986/1261 [02:08<00:38,  7.07it/s]
#  78%|███████▊  | 987/1261 [02:08<00:39,  6.97it/s]
#  78%|███████▊  | 988/1261 [02:08<00:39,  6.86it/s]
#  78%|███████▊  | 989/1261 [02:08<00:40,  6.75it/s]
#  79%|███████▊  | 990/1261 [02:08<00:40,  6.72it/s]
#  79%|███████▊  | 991/1261 [02:08<00:39,  6.80it/s]
#  79%|███████▊  | 992/1261 [02:08<00:39,  6.80it/s]
#  79%|███████▊  | 993/1261 [02:09<00:38,  6.90it/s]
#  79%|███████▉  | 994/1261 [02:09<00:38,  6.99it/s]
#  79%|███████▉  | 995/1261 [02:09<00:37,  7.09it/s]
#  79%|███████▉  | 996/1261 [02:09<00:37,  6.98it/s]
#  79%|███████▉  | 997/1261 [02:09<00:37,  7.09it/s]
#  79%|███████▉  | 998/1261 [02:09<00:36,  7.18it/s]
#  79%|███████▉  | 999/1261 [02:09<00:36,  7.20it/s]
#  79%|███████▉  | 1000/1261 [02:10<00:36,  7.09it/s]
#  79%|███████▉  | 1001/1261 [02:10<00:36,  7.13it/s]
#  79%|███████▉  | 1002/1261 [02:10<00:35,  7.20it/s]
#  80%|███████▉  | 1003/1261 [02:10<00:35,  7.26it/s]
#  80%|███████▉  | 1004/1261 [02:10<00:36,  7.14it/s]
#  80%|███████▉  | 1005/1261 [02:10<00:35,  7.20it/s]
#  80%|███████▉  | 1006/1261 [02:10<00:35,  7.27it/s]
#  80%|███████▉  | 1007/1261 [02:11<00:34,  7.31it/s]
#  80%|███████▉  | 1008/1261 [02:11<00:35,  7.17it/s]
#  80%|████████  | 1009/1261 [02:11<00:34,  7.22it/s]
#  80%|████████  | 1010/1261 [02:11<00:35,  7.16it/s]
#  80%|████████  | 1011/1261 [02:11<00:34,  7.23it/s]
#  80%|████████  | 1012/1261 [02:11<00:35,  7.11it/s]
#  80%|████████  | 1013/1261 [02:11<00:34,  7.15it/s]
#  80%|████████  | 1014/1261 [02:11<00:34,  7.19it/s]
#  80%|████████  | 1015/1261 [02:12<00:33,  7.29it/s]
#  81%|████████  | 1016/1261 [02:12<00:34,  7.09it/s]
#  81%|████████  | 1017/1261 [02:12<00:33,  7.18it/s]
#  81%|████████  | 1018/1261 [02:12<00:33,  7.23it/s]
#  81%|████████  | 1019/1261 [02:12<00:33,  7.25it/s]
#  81%|████████  | 1020/1261 [02:12<00:34,  7.08it/s]
#  81%|████████  | 1021/1261 [02:12<00:33,  7.25it/s]
#  81%|████████  | 1022/1261 [02:13<00:32,  7.41it/s]
#  81%|████████  | 1023/1261 [02:13<00:31,  7.57it/s]
#  81%|████████  | 1024/1261 [02:13<00:31,  7.47it/s]
#  81%|████████▏ | 1025/1261 [02:13<00:31,  7.58it/s]
#  81%|████████▏ | 1026/1261 [02:13<00:30,  7.76it/s]
#  81%|████████▏ | 1027/1261 [02:13<00:29,  8.06it/s]
#  82%|████████▏ | 1028/1261 [02:13<00:28,  8.04it/s]
#  82%|████████▏ | 1029/1261 [02:13<00:28,  8.23it/s]
#  82%|████████▏ | 1030/1261 [02:14<00:27,  8.43it/s]
#  82%|████████▏ | 1031/1261 [02:14<00:26,  8.62it/s]
#  82%|████████▏ | 1032/1261 [02:14<00:27,  8.48it/s]
#  82%|████████▏ | 1033/1261 [02:14<00:26,  8.53it/s]
#  82%|████████▏ | 1034/1261 [02:14<00:26,  8.66it/s]
#  82%|████████▏ | 1035/1261 [02:14<00:26,  8.65it/s]
#  82%|████████▏ | 1036/1261 [02:14<00:26,  8.57it/s]
#  82%|████████▏ | 1037/1261 [02:14<00:25,  8.65it/s]
#  82%|████████▏ | 1038/1261 [02:14<00:25,  8.67it/s]
#  82%|████████▏ | 1039/1261 [02:15<00:25,  8.62it/s]
#  82%|████████▏ | 1040/1261 [02:15<00:25,  8.63it/s]
#  83%|████████▎ | 1041/1261 [02:15<00:25,  8.68it/s]
#  83%|████████▎ | 1042/1261 [02:15<00:24,  9.01it/s]
#  83%|████████▎ | 1044/1261 [02:15<00:24,  9.02it/s]
#  83%|████████▎ | 1045/1261 [02:15<00:23,  9.03it/s]
#  83%|████████▎ | 1046/1261 [02:15<00:24,  8.96it/s]
#  83%|████████▎ | 1047/1261 [02:15<00:23,  8.97it/s]
#  83%|████████▎ | 1048/1261 [02:16<00:24,  8.56it/s]
#  83%|████████▎ | 1049/1261 [02:16<00:24,  8.51it/s]
#  83%|████████▎ | 1050/1261 [02:16<00:25,  8.43it/s]
#  83%|████████▎ | 1051/1261 [02:16<00:25,  8.23it/s]
#  83%|████████▎ | 1052/1261 [02:16<00:26,  7.99it/s]
#  84%|████████▎ | 1053/1261 [02:16<00:26,  7.88it/s]
#  84%|████████▎ | 1054/1261 [02:16<00:27,  7.54it/s]
#  84%|████████▎ | 1055/1261 [02:17<00:26,  7.66it/s]
#  84%|████████▎ | 1056/1261 [02:17<00:25,  7.92it/s]
#  84%|████████▍ | 1057/1261 [02:17<00:25,  8.07it/s]
#  84%|████████▍ | 1058/1261 [02:17<00:24,  8.19it/s]
#  84%|████████▍ | 1059/1261 [02:17<00:24,  8.28it/s]
#  84%|████████▍ | 1060/1261 [02:17<00:23,  8.42it/s]
#  84%|████████▍ | 1061/1261 [02:17<00:23,  8.49it/s]
#  84%|████████▍ | 1062/1261 [02:17<00:23,  8.51it/s]
#  84%|████████▍ | 1063/1261 [02:17<00:23,  8.59it/s]
#  84%|████████▍ | 1064/1261 [02:18<00:22,  8.64it/s]
#  84%|████████▍ | 1065/1261 [02:18<00:22,  8.66it/s]
#  85%|████████▍ | 1066/1261 [02:18<00:23,  8.26it/s]
#  85%|████████▍ | 1067/1261 [02:18<00:24,  8.07it/s]
#  85%|████████▍ | 1068/1261 [02:18<00:23,  8.12it/s]
#  85%|████████▍ | 1069/1261 [02:18<00:23,  8.21it/s]
#  85%|████████▍ | 1070/1261 [02:18<00:24,  7.96it/s]
#  85%|████████▍ | 1071/1261 [02:18<00:24,  7.72it/s]
#  85%|████████▌ | 1072/1261 [02:19<00:24,  7.65it/s]
#  85%|████████▌ | 1073/1261 [02:19<00:24,  7.62it/s]
#  85%|████████▌ | 1074/1261 [02:19<00:25,  7.47it/s]
#  85%|████████▌ | 1075/1261 [02:19<00:24,  7.46it/s]
#  85%|████████▌ | 1076/1261 [02:19<00:24,  7.44it/s]
#  85%|████████▌ | 1077/1261 [02:19<00:24,  7.51it/s]
#  85%|████████▌ | 1078/1261 [02:19<00:24,  7.47it/s]
#  86%|████████▌ | 1079/1261 [02:20<00:23,  7.59it/s]
#  86%|████████▌ | 1080/1261 [02:20<00:23,  7.69it/s]
#  86%|████████▌ | 1081/1261 [02:20<00:23,  7.68it/s]
#  86%|████████▌ | 1082/1261 [02:20<00:23,  7.71it/s]
#  86%|████████▌ | 1083/1261 [02:20<00:22,  7.86it/s]
#  86%|████████▌ | 1084/1261 [02:20<00:21,  8.05it/s]
#  86%|████████▌ | 1085/1261 [02:20<00:21,  8.08it/s]
#  86%|████████▌ | 1086/1261 [02:20<00:21,  7.97it/s]
#  86%|████████▌ | 1087/1261 [02:21<00:22,  7.88it/s]
#  86%|████████▋ | 1088/1261 [02:21<00:21,  7.92it/s]
#  86%|████████▋ | 1089/1261 [02:21<00:22,  7.70it/s]
#  86%|████████▋ | 1090/1261 [02:21<00:22,  7.69it/s]
#  87%|████████▋ | 1091/1261 [02:21<00:22,  7.63it/s]
#  87%|████████▋ | 1092/1261 [02:21<00:22,  7.60it/s]
#  87%|████████▋ | 1093/1261 [02:21<00:21,  7.77it/s]
#  87%|████████▋ | 1094/1261 [02:21<00:23,  7.07it/s]
#  87%|████████▋ | 1095/1261 [02:22<00:23,  7.21it/s]
#  87%|████████▋ | 1096/1261 [02:22<00:23,  7.11it/s]
#  87%|████████▋ | 1097/1261 [02:22<00:22,  7.17it/s]
#  87%|████████▋ | 1098/1261 [02:22<00:22,  7.17it/s]
#  87%|████████▋ | 1099/1261 [02:22<00:22,  7.24it/s]
#  87%|████████▋ | 1100/1261 [02:22<00:22,  7.28it/s]
#  87%|████████▋ | 1101/1261 [02:22<00:21,  7.35it/s]
#  87%|████████▋ | 1102/1261 [02:23<00:21,  7.35it/s]
#  87%|████████▋ | 1103/1261 [02:23<00:21,  7.37it/s]
#  88%|████████▊ | 1104/1261 [02:23<00:21,  7.39it/s]
#  88%|████████▊ | 1105/1261 [02:23<00:21,  7.41it/s]
#  88%|████████▊ | 1106/1261 [02:23<00:20,  7.46it/s]
#  88%|████████▊ | 1107/1261 [02:23<00:21,  7.31it/s]
#  88%|████████▊ | 1108/1261 [02:23<00:21,  7.17it/s]
#  88%|████████▊ | 1109/1261 [02:24<00:20,  7.29it/s]
#  88%|████████▊ | 1110/1261 [02:24<00:20,  7.34it/s]
#  88%|████████▊ | 1111/1261 [02:24<00:21,  6.99it/s]
#  88%|████████▊ | 1112/1261 [02:24<00:21,  7.03it/s]
#  88%|████████▊ | 1113/1261 [02:24<00:21,  6.88it/s]
#  88%|████████▊ | 1114/1261 [02:24<00:21,  6.87it/s]
#  88%|████████▊ | 1115/1261 [02:24<00:21,  6.80it/s]
#  89%|████████▊ | 1116/1261 [02:25<00:21,  6.68it/s]
#  89%|████████▊ | 1117/1261 [02:25<00:21,  6.77it/s]
#  89%|████████▊ | 1118/1261 [02:25<00:20,  6.94it/s]
#  89%|████████▊ | 1119/1261 [02:25<00:20,  6.99it/s]
#  89%|████████▉ | 1120/1261 [02:25<00:19,  7.08it/s]
#  89%|████████▉ | 1121/1261 [02:25<00:20,  6.77it/s]
#  89%|████████▉ | 1122/1261 [02:25<00:20,  6.77it/s]
#  89%|████████▉ | 1123/1261 [02:26<00:20,  6.76it/s]
#  89%|████████▉ | 1124/1261 [02:26<00:20,  6.79it/s]
#  89%|████████▉ | 1125/1261 [02:26<00:19,  6.85it/s]
#  89%|████████▉ | 1126/1261 [02:26<00:19,  7.00it/s]
#  89%|████████▉ | 1127/1261 [02:26<00:19,  6.93it/s]
#  89%|████████▉ | 1128/1261 [02:26<00:19,  6.86it/s]
#  90%|████████▉ | 1129/1261 [02:26<00:19,  6.81it/s]
#  90%|████████▉ | 1130/1261 [02:27<00:19,  6.87it/s]
#  90%|████████▉ | 1131/1261 [02:27<00:19,  6.57it/s]
#  90%|████████▉ | 1132/1261 [02:27<00:19,  6.59it/s]
#  90%|████████▉ | 1133/1261 [02:27<00:18,  6.78it/s]
#  90%|████████▉ | 1134/1261 [02:27<00:18,  6.94it/s]
#  90%|█████████ | 1135/1261 [02:27<00:18,  6.96it/s]
#  90%|█████████ | 1136/1261 [02:27<00:17,  7.05it/s]
#  90%|█████████ | 1137/1261 [02:28<00:17,  7.17it/s]
#  90%|█████████ | 1138/1261 [02:28<00:16,  7.27it/s]
#  90%|█████████ | 1139/1261 [02:28<00:17,  7.17it/s]
#  90%|█████████ | 1140/1261 [02:28<00:16,  7.21it/s]
#  90%|█████████ | 1141/1261 [02:28<00:16,  7.15it/s]
#  91%|█████████ | 1142/1261 [02:28<00:17,  6.99it/s]
#  91%|█████████ | 1143/1261 [02:28<00:17,  6.94it/s]
#  91%|█████████ | 1144/1261 [02:29<00:16,  7.03it/s]
#  91%|█████████ | 1145/1261 [02:29<00:16,  7.17it/s]
#  91%|█████████ | 1146/1261 [02:29<00:15,  7.22it/s]
#  91%|█████████ | 1147/1261 [02:29<00:16,  6.95it/s]
#  91%|█████████ | 1148/1261 [02:29<00:16,  6.80it/s]
#  91%|█████████ | 1149/1261 [02:29<00:16,  6.96it/s]
#  91%|█████████ | 1150/1261 [02:29<00:15,  7.10it/s]
#  91%|█████████▏| 1151/1261 [02:30<00:15,  7.06it/s]
#  91%|█████████▏| 1152/1261 [02:30<00:15,  7.19it/s]
#  91%|█████████▏| 1153/1261 [02:30<00:14,  7.30it/s]
#  92%|█████████▏| 1154/1261 [02:30<00:17,  6.22it/s]
#  92%|█████████▏| 1155/1261 [02:30<00:17,  6.14it/s]
#  92%|█████████▏| 1156/1261 [02:30<00:16,  6.45it/s]
#  92%|█████████▏| 1157/1261 [02:31<00:15,  6.59it/s]
#  92%|█████████▏| 1158/1261 [02:31<00:15,  6.84it/s]
#  92%|█████████▏| 1159/1261 [02:31<00:14,  6.91it/s]
#  92%|█████████▏| 1160/1261 [02:31<00:14,  7.01it/s]
#  92%|█████████▏| 1161/1261 [02:31<00:13,  7.19it/s]
#  92%|█████████▏| 1162/1261 [02:31<00:13,  7.27it/s]
#  92%|█████████▏| 1163/1261 [02:31<00:13,  7.14it/s]
#  92%|█████████▏| 1164/1261 [02:31<00:13,  7.18it/s]
#  92%|█████████▏| 1165/1261 [02:32<00:13,  7.35it/s]
#  92%|█████████▏| 1166/1261 [02:32<00:13,  7.22it/s]
#  93%|█████████▎| 1167/1261 [02:32<00:13,  7.16it/s]
#  93%|█████████▎| 1168/1261 [02:32<00:12,  7.29it/s]
#  93%|█████████▎| 1169/1261 [02:32<00:12,  7.41it/s]
#  93%|█████████▎| 1170/1261 [02:32<00:12,  7.54it/s]
#  93%|█████████▎| 1171/1261 [02:32<00:12,  7.47it/s]
#  93%|█████████▎| 1172/1261 [02:33<00:11,  7.53it/s]
#  93%|█████████▎| 1173/1261 [02:33<00:11,  7.61it/s]
#  93%|█████████▎| 1174/1261 [02:33<00:11,  7.69it/s]
#  93%|█████████▎| 1175/1261 [02:33<00:11,  7.52it/s]
#  93%|█████████▎| 1176/1261 [02:33<00:11,  7.55it/s]
#  93%|█████████▎| 1177/1261 [02:33<00:11,  7.59it/s]
#  93%|█████████▎| 1178/1261 [02:33<00:10,  7.61it/s]
#  93%|█████████▎| 1179/1261 [02:33<00:10,  7.46it/s]
#  94%|█████████▎| 1180/1261 [02:34<00:10,  7.45it/s]
#  94%|█████████▎| 1181/1261 [02:34<00:10,  7.56it/s]
#  94%|█████████▎| 1182/1261 [02:34<00:10,  7.58it/s]
#  94%|█████████▍| 1183/1261 [02:34<00:10,  7.45it/s]
#  94%|█████████▍| 1184/1261 [02:34<00:10,  7.52it/s]
#  94%|█████████▍| 1185/1261 [02:34<00:10,  7.57it/s]
#  94%|█████████▍| 1186/1261 [02:34<00:09,  7.63it/s]
#  94%|█████████▍| 1187/1261 [02:35<00:09,  7.54it/s]
#  94%|█████████▍| 1188/1261 [02:35<00:09,  7.53it/s]
#  94%|█████████▍| 1189/1261 [02:35<00:09,  7.57it/s]
#  94%|█████████▍| 1190/1261 [02:35<00:09,  7.62it/s]
#  94%|█████████▍| 1191/1261 [02:35<00:09,  7.16it/s]
#  95%|█████████▍| 1192/1261 [02:35<00:09,  7.10it/s]
#  95%|█████████▍| 1193/1261 [02:35<00:09,  7.21it/s]
#  95%|█████████▍| 1194/1261 [02:36<00:09,  7.05it/s]
#  95%|█████████▍| 1195/1261 [02:36<00:09,  6.89it/s]
#  95%|█████████▍| 1196/1261 [02:36<00:09,  6.93it/s]
#  95%|█████████▍| 1197/1261 [02:36<00:08,  7.16it/s]
#  95%|█████████▌| 1198/1261 [02:36<00:08,  7.29it/s]
#  95%|█████████▌| 1199/1261 [02:36<00:08,  7.13it/s]
#  95%|█████████▌| 1200/1261 [02:36<00:08,  7.27it/s]
#  95%|█████████▌| 1201/1261 [02:36<00:08,  7.40it/s]
#  95%|█████████▌| 1202/1261 [02:37<00:07,  7.57it/s]
#  95%|█████████▌| 1203/1261 [02:37<00:07,  7.55it/s]
#  95%|█████████▌| 1204/1261 [02:37<00:07,  7.48it/s]
#  96%|█████████▌| 1205/1261 [02:37<00:08,  6.96it/s]
#  96%|█████████▌| 1206/1261 [02:37<00:07,  7.04it/s]
#  96%|█████████▌| 1207/1261 [02:37<00:07,  7.19it/s]
#  96%|█████████▌| 1208/1261 [02:37<00:07,  7.35it/s]
#  96%|█████████▌| 1209/1261 [02:38<00:06,  7.44it/s]
#  96%|█████████▌| 1210/1261 [02:38<00:06,  7.50it/s]
#  96%|█████████▌| 1211/1261 [02:38<00:06,  7.30it/s]
#  96%|█████████▌| 1212/1261 [02:38<00:06,  7.44it/s]
#  96%|█████████▌| 1213/1261 [02:38<00:06,  7.53it/s]
#  96%|█████████▋| 1214/1261 [02:38<00:06,  7.62it/s]
#  96%|█████████▋| 1215/1261 [02:38<00:06,  7.48it/s]
#  96%|█████████▋| 1216/1261 [02:39<00:06,  7.48it/s]
#  97%|█████████▋| 1217/1261 [02:39<00:05,  7.53it/s]
#  97%|█████████▋| 1218/1261 [02:39<00:05,  7.61it/s]
#  97%|█████████▋| 1219/1261 [02:39<00:05,  7.56it/s]
#  97%|█████████▋| 1220/1261 [02:39<00:05,  7.50it/s]
#  97%|█████████▋| 1221/1261 [02:39<00:05,  7.55it/s]
#  97%|█████████▋| 1222/1261 [02:39<00:05,  7.64it/s]
#  97%|█████████▋| 1223/1261 [02:39<00:04,  7.70it/s]
#  97%|█████████▋| 1224/1261 [02:40<00:04,  7.58it/s]
#  97%|█████████▋| 1225/1261 [02:40<00:04,  7.61it/s]
#  97%|█████████▋| 1226/1261 [02:40<00:04,  7.66it/s]
#  97%|█████████▋| 1227/1261 [02:40<00:04,  7.66it/s]
#  97%|█████████▋| 1228/1261 [02:40<00:04,  7.61it/s]
#  97%|█████████▋| 1229/1261 [02:40<00:04,  7.63it/s]
#  98%|█████████▊| 1230/1261 [02:40<00:04,  7.69it/s]
#  98%|█████████▊| 1231/1261 [02:40<00:03,  7.70it/s]
#  98%|█████████▊| 1232/1261 [02:41<00:03,  7.53it/s]
#  98%|█████████▊| 1233/1261 [02:41<00:03,  7.55it/s]
#  98%|█████████▊| 1234/1261 [02:41<00:03,  7.59it/s]
#  98%|█████████▊| 1235/1261 [02:41<00:03,  7.63it/s]
#  98%|█████████▊| 1236/1261 [02:41<00:03,  7.56it/s]
#  98%|█████████▊| 1237/1261 [02:41<00:03,  7.53it/s]
#  98%|█████████▊| 1238/1261 [02:41<00:03,  7.57it/s]
#  98%|█████████▊| 1239/1261 [02:42<00:02,  7.65it/s]
#  98%|█████████▊| 1240/1261 [02:42<00:02,  7.48it/s]
#  98%|█████████▊| 1241/1261 [02:42<00:02,  7.53it/s]
#  98%|█████████▊| 1242/1261 [02:42<00:02,  7.61it/s]
#  99%|█████████▊| 1243/1261 [02:42<00:02,  7.68it/s]
#  99%|█████████▊| 1244/1261 [02:42<00:02,  7.46it/s]
#  99%|█████████▊| 1245/1261 [02:42<00:02,  7.47it/s]
#  99%|█████████▉| 1246/1261 [02:42<00:01,  7.54it/s]
#  99%|█████████▉| 1247/1261 [02:43<00:01,  7.60it/s]
#  99%|█████████▉| 1248/1261 [02:43<00:01,  7.50it/s]
#  99%|█████████▉| 1249/1261 [02:43<00:01,  7.54it/s]
#  99%|█████████▉| 1250/1261 [02:43<00:01,  7.67it/s]
#  99%|█████████▉| 1251/1261 [02:43<00:01,  7.90it/s]
#  99%|█████████▉| 1252/1261 [02:43<00:01,  7.90it/s]
#  99%|█████████▉| 1253/1261 [02:43<00:00,  8.02it/s]
#  99%|█████████▉| 1254/1261 [02:43<00:00,  8.00it/s]
# 100%|█████████▉| 1255/1261 [02:44<00:00,  7.63it/s]
# 100%|█████████▉| 1256/1261 [02:44<00:00,  7.44it/s]
# 100%|█████████▉| 1257/1261 [02:44<00:00,  7.55it/s]
# 100%|█████████▉| 1258/1261 [02:44<00:00,  7.67it/s]
# 100%|█████████▉| 1259/1261 [02:44<00:00,  7.83it/s]
# 100%|█████████▉| 1260/1261 [02:44<00:00,  7.82it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: video_output.mp4
#
# CPU times: user 3min 11s, sys: 22.7 s, total: 3min 33s
# Wall time: 2min 45s
